# %%
from datasets import load_dataset
from huggingface_hub import login
import tiktoken
import pandas as pd
import numpy as np
from transformers import AutoModelForCausalLM, AutoTokenizer
from tqdm import tqdm
import re, json
from glob import glob
# Import missing libraries
import multiprocessing
from concurrent.futures import ProcessPoolExecutor
import os

# %%
def evaluate_and_characterize_failures(trajectory, target, nums, tokenizer=AutoTokenizer.from_pretrained("Qwen/Qwen2.5-1.5B-Instruct")) -> dict:
    """
    Evaluates a countdown task trajectory and returns detailed diagnosis information
    for all error types, plus equation statistics.
    
    Args:
        trajectory (str): The reasoning trajectory text
        target (int/float): The target number to reach
        nums (list): List of starting numbers available
    
    Returns:
        dict: Results containing various error indicators and statistics
    """
    import re
    import ast
    import math
    from typing import List

    # Initialize error flags
    is_valid = True
    arithmetic_error = False
    sign_error = False
    invalid_number_usage = False
    formatting_issues = False
    token_count = len(tokenizer(trajectory)["input_ids"])
    
    # Initialize equation counters
    total_equations = 0
    arithmetic_error_count = 0
    sign_error_count = 0
    
    # Initialize heuristic calculation tracking
    heuristic_calculation_count = 0
    heuristic_arithmetic_errors = 0
    
    # Initialize node tracking
    nodes = {}
    node_recall_errors = 0
    
    # Enhanced pattern to capture both "=" and "is" as equation separators with flexible spacing
    equation_pattern = re.compile(r"([\d.]+)\s*([\+\-\*/])\s*([\d.]+)\s*(?:=|is)\s*([\d.]+)")
    all_equations = equation_pattern.findall(trajectory)
    
    total_equations = len(all_equations)
    
    # Check each equation for arithmetic correctness and sign errors
    for eq in all_equations:
        try:
            num1 = float(eq[0])
            op = eq[1]
            num2 = float(eq[2])
            result = float(eq[3])
            
            # Calculate the expected result
            if op == '+':
                expected = num1 + num2
            elif op == '-':
                expected = num1 - num2
            elif op == '*':
                expected = num1 * num2
            elif op == '/':
                if math.isclose(num2, 0.0):
                    arithmetic_error_count += 1
                    continue
                expected = num1 / num2
            else:
                # Invalid operator
                continue
                
            # Compare expected vs. given result
            if not math.isclose(expected, result, rel_tol=1e-5):
                arithmetic_error_count += 1
                
                # Check for sign error (same absolute value but wrong sign)
                if math.isclose(abs(expected), abs(result), rel_tol=1e-5) and math.copysign(1, expected) != math.copysign(1, result):
                    sign_error_count += 1
                
        except Exception:
            # Skip equations with parsing issues
            continue
    
    # Track node definitions
    node_pattern = re.compile(r"Node (\d+):\s*nums=\[([\d, ]+)\]")
    for match in node_pattern.finditer(trajectory):
        node_id = match.group(1)
        nums_str = match.group(2)
        try:
            nums_list = [int(n.strip()) for n in nums_str.split(",") if n.strip()]
            
            # Check if node was already seen and numbers differ
            if node_id in nodes:
                if set(nums_list) != set(nodes[node_id]):
                    node_recall_errors += 1
            else:
                nodes[node_id] = nums_list
        except:
            pass  # Skip if there's an issue parsing the numbers
    
    # Find and validate heuristic score calculations
    # Pattern for simple heuristic count
    heuristic_pattern = re.compile(r"Heuristic score\s*:", re.IGNORECASE)
    heuristic_lines = [m.start() for m in re.finditer(heuristic_pattern, trajectory)]
    heuristic_calculation_count = len(heuristic_lines)
    
    # Detailed pattern for validating the arithmetic in heuristic calculations
    # This is complex and may need tuning based on actual format
    heuristic_calc_pattern = re.compile(
        r"Heuristic score\s*:\s*\((.*?)\)/(\d+)\s*=\s*(.*?)\s*=\s*([\d.]+)", 
        re.IGNORECASE
    )
    
    for match in heuristic_calc_pattern.finditer(trajectory):
        # Extract the parts of the calculation
        expressions_part = match.group(1)  # e.g. "|9-20| + |67-20| + |57-20|"
        divisor = int(match.group(2))      # e.g. 3
        sums_part = match.group(3)         # e.g. "(11 + 47 + 37)"        
        float_num = match.group(4)
        try:
            # remove all the . at the end of the float_num
            float_num = re.sub(r'\.+$', '', float_num)
            claimed_result = float(float_num)  # e.g. 30.33
        except Exception as e:
            print("Not just elipses issue, parsing as None: ", e)
            # if elipses issue
            claimed_result = None    
                    
        # Find individual absolute values in the expression
        abs_values = []
        try:
            # Extract values from sums part (e.g. "11 + 47 + 37")
            terms = re.findall(r'(\d+(?:\.\d+)?)', sums_part)
            abs_values = [float(t) for t in terms]
            
            # Calculate expected result
            expected_sum = sum(abs_values)
            expected_result = expected_sum / divisor
            
            # Compare with claimed result
            if not math.isclose(expected_result, claimed_result, rel_tol=1e-2):
                heuristic_arithmetic_errors += 1
        except:
            # If we can't fully parse the heuristic calculation, just count it
            pass
    
    # Check for incomplete trajectory
    if not re.search(r"RESULT:", trajectory):
        incomplete_trajectory = True
        is_valid = False
    
    # Check for formatting: SOLUTION field
    sol_match = re.search(r"SOLUTION:\s*(YES|NO)", trajectory, re.IGNORECASE)
    if not sol_match:
        formatting_issues = True
        is_valid = False
    else:
        sol_decl = sol_match.group(1).upper()
        if sol_decl != "YES":
            is_valid = False
    
    # Extract OPERATIONS list
    operations = []
    ops_match = re.search(r"OPERATIONS:\s*(\[[^\]]*\])", trajectory, re.DOTALL)
    if not ops_match:
        formatting_issues = True
        is_valid = False
    else:
        try:
            operations = ast.literal_eval(ops_match.group(1))
            if not isinstance(operations, list):
                formatting_issues = True
                is_valid = False
        except Exception:
            formatting_issues = True
            is_valid = False
    
    # Extract final RESULT
    expected_final = None
    res_match = re.search(r"RESULT:\s*([-+.\d]+)", trajectory)
    if not res_match:
        formatting_issues = True
        is_valid = False
    else:
        try:
            expected_final = float(res_match.group(1))
        except Exception:
            formatting_issues = True
            is_valid = False
    
    # If we have severe formatting issues, we can't proceed with arithmetic and usage checks
    if formatting_issues or not operations:
        return {
            "is_valid": is_valid,
            "arithmetic_error": arithmetic_error,
            "sign_error": sign_error,
            "invalid_number_usage": invalid_number_usage,
            "formatting_issues": formatting_issues,
            "total_equations": total_equations,
            "arithmetic_error_count": arithmetic_error_count,
            "token_count": token_count,
            "sign_error_count": sign_error_count,
            "heuristic_calculation_count": heuristic_calculation_count,
            "heuristic_arithmetic_errors": heuristic_arithmetic_errors,
            "node_recall_errors": node_recall_errors
        }
    
    # Simulation: available numbers (as floats)
    available = [float(n) for n in nums]
    
    # Enhanced operation pattern for validation
    op_pattern = re.compile(r"^\s*([\d.]+)\s*([\+\-\*/])\s*([\d.]+)\s*(?:=|is)\s*([\d.]+)\s*$")
    
    operation_results = []  # Store results to check if all numbers were used
    
    for op_str in operations:
        m = op_pattern.match(op_str)
        if not m:
            formatting_issues = True
            is_valid = False
            continue
        
        op1_str, operator, op2_str, given_result_str = m.groups()
        try:
            op1 = float(op1_str)
            op2 = float(op2_str)
            op_result = float(given_result_str)
        except Exception:
            formatting_issues = True
            is_valid = False
            continue
        
        # Check arithmetic correctness
        try:
            if operator == '+':
                computed = op1 + op2
            elif operator == '-':
                computed = op1 - op2
            elif operator == '*':
                computed = op1 * op2
            elif operator == '/':
                if math.isclose(op2, 0.0):
                    arithmetic_error = True
                    is_valid = False
                    continue
                computed = op1 / op2
            else:
                formatting_issues = True
                is_valid = False
                continue
                
            if not math.isclose(computed, op_result, rel_tol=1e-5):
                arithmetic_error = True
                is_valid = False
                
                # Check for sign error (same absolute value but wrong sign)
                if math.isclose(abs(computed), abs(op_result), rel_tol=1e-5):
                    sign_error_count += 1
                    sign_error = True
        except Exception:
            arithmetic_error = True
            is_valid = False
            continue
        
        operation_results.append((op1, op2, op_result))
    
    # Check for invalid number usage by simulating all operations
    if operation_results:
        try:
            # Reset available numbers for a fresh check
            available = [float(n) for n in nums]
            
            def consume(value, pool):
                for i, num in enumerate(pool):
                    if math.isclose(num, value, rel_tol=1e-5):
                        del pool[i]
                        return True
                return False
            
            for op1, op2, result in operation_results:
                if not consume(op1, available):
                    invalid_number_usage = True
                    is_valid = False
                    break
                
                if not consume(op2, available):
                    invalid_number_usage = True
                    is_valid = False
                    break
                
                available.append(result)
            
            # After all operations, should have exactly one number equal to target
            if len(available) != 1:
                invalid_number_usage = True
                is_valid = False
            elif expected_final is not None and not math.isclose(available[0], float(target), rel_tol=1e-5):
                arithmetic_error = True
                is_valid = False
                
        except Exception:
            invalid_number_usage = True
            is_valid = False
    
    return {
        "is_valid": is_valid,
        "arithmetic_error": arithmetic_error,
        "sign_error": sign_error,
        "invalid_number_usage": invalid_number_usage, 
        "formatting_issues": formatting_issues,
        "total_equations": total_equations,
        "arithmetic_error_count": arithmetic_error_count,
        "token_count": token_count,
        "sign_error_count": sign_error_count,
        "heuristic_calculation_count": heuristic_calculation_count,
        "heuristic_arithmetic_errors": heuristic_arithmetic_errors,
        "node_recall_errors": node_recall_errors
    }

# %%
def parse_model_filepath(filepath):
    """
    Parse a model filepath to extract model size, dataset type, context length, and dataset size.
    
    Args:
        filepath (str): Path to the model file
        
    Returns:
        dict: Dictionary containing model_size, dataset_type, context_length, and dataset_size
    """
    # Extract the directory part of the path
    directory = os.path.dirname(filepath)
    # Get the last part of the directory path (the model folder name)
    model_folder = os.path.basename(directory)
    
    # Initialize result dictionary
    result = {
        "model_size": None,
        "dataset_type": None,
        "context_length": None,
        "dataset_size": None
    }
    
    # Extract model size (e.g., 0.5B, 1.5B)
    model_size_match = re.search(r'(\d+\.\d+B)', model_folder)
    if model_size_match:
        result["model_size"] = model_size_match.group(1)
    
    # Extract dataset type (e.g., o3, search, search-react)
    # We need to handle special cases like "search-react" and "search-long"
    if "search-react" in model_folder:
        result["dataset_type"] = "search-react"
    elif "search-long" in model_folder:
        result["dataset_type"] = "search-long"
    elif "search" in model_folder:
        result["dataset_type"] = "search"
    elif "optimal" in model_folder:
        result["dataset_type"] = "optimal"
    elif "o3" in model_folder:
        result["dataset_type"] = "o3"
    
    # Extract context length (e.g., 8k from seq8k)
    context_match = re.search(r'seq(\d+k)', model_folder)
    if context_match:
        result["context_length"] = context_match.group(1)
    else:
        result["context_length"] = "4k"  # Default to 4k if not found
    
    # Extract dataset size (e.g., 1k, 5k)
    # This is typically the last part of the model folder name
    dataset_size_match = re.search(r'(\d+k)(?:/|$)', model_folder)
    if dataset_size_match:
        result["dataset_size"] = dataset_size_match.group(1)
    
    return result

def find_experiment_files(base_dir, pattern="**/test_128*.json"):
    """Find all experiment result files in the given directory."""
    return glob(os.path.join(base_dir, pattern), recursive=True)

def process_trajectories_to_dataframe(file_path):
    """
    Process a single results file and convert trajectories to a pandas DataFrame
    with metadata and evaluation results.
    
    Args:
        file_path (str): Path to the JSON file
        
    Returns:
        pd.DataFrame: DataFrame with trajectories and their evaluations
    """
    try:
        with open(file_path, 'r') as f:
            data = json.load(f)
        
        # Skip the first two elements as per requirements
        if len(data) <= 2:
            print(f"Warning: {os.path.basename(file_path)} has fewer than 3 elements. Skipping.")
            return pd.DataFrame()
            
        trajectories = data[2:]  # Start from the 3rd element
        
        # Get model metadata
        model_info = parse_model_filepath(file_path)
        
        # Process each trajectory
        trajectories_results = []
        for idx, row in enumerate(trajectories):
            result = evaluate_and_characterize_failures(
                row["completion"], 
                row["target"], 
                row["nums"]
            )
            
            # Add trajectory data and model metadata
            result["trajectory_index"] = idx
            result["completion"] = row["completion"]
            result["target"] = row["target"]
            result["nums"] = row["nums"]
            result["file_path"] = file_path
            
            # Add model metadata
            for key, value in model_info.items():
                result[key] = value
                
            trajectories_results.append(result)
        
        return pd.DataFrame(trajectories_results)
        
    except Exception as e:
        print(f"Error processing {file_path}: {str(e)}")
        return pd.DataFrame()

def calculate_statistics_for_group(group_data):
    """Helper function to calculate statistics for a group of trajectories"""
    file_path, file_df = group_data
    
    # Get model info once (same for all rows in this group)
    model_info = {
        "model_size": file_df["model_size"].iloc[0],
        "dataset_type": file_df["dataset_type"].iloc[0],
        "context_length": file_df["context_length"].iloc[0],
        "dataset_size": file_df["dataset_size"].iloc[0]
    }
    
    # Calculate statistics
    total_rows = len(file_df)
    max_tokens = file_df["token_count"].max()
    
    # Get counts of various issues
    total_is_valid = file_df["is_valid"].sum()
    total_has_arithmetic_error = file_df["arithmetic_error"].sum()
    total_has_sign_error = file_df["sign_error"].sum()
    total_has_invalid_number = file_df["invalid_number_usage"].sum()
    total_has_formatting_issues = file_df["formatting_issues"].sum()

    # Calculate incomplete trajectories
    max_token_count_occurrences = (file_df["token_count"] == max_tokens).sum()
    total_has_formatting_issues_and_reach_max_tokens = 0

    if max_token_count_occurrences >= 2:
        # Only count incomplete trajectories if we have at least 2 trajectories with max token count
        total_has_formatting_issues_and_reach_max_tokens = ((file_df["formatting_issues"]) & 
                                                np.isclose(file_df["token_count"],max_tokens, 1e-2)).sum()
        total_has_formatting_issues = ((file_df["formatting_issues"]) & 
                                            (np.isclose(file_df["token_count"],max_tokens, 1e-2)==False)).sum()

    # Calculate percentage of arithmetic errors per trajectory
    arithmetic_error_percentages = []
    for _, row in file_df.iterrows():
        if row["total_equations"] > 0:
            error_percentage = row["arithmetic_error_count"] / row["total_equations"]
            arithmetic_error_percentages.append(error_percentage)
        else:
            arithmetic_error_percentages.append(0.0)

    # Calculate mean percentage of arithmetic errors
    mean_percentage_arithmetic_error = 0
    if arithmetic_error_percentages:
        mean_percentage_arithmetic_error = sum(arithmetic_error_percentages) / len(arithmetic_error_percentages)
    
    # Create statistics dictionary
    stats = model_info.copy()
    stats.update({
        "total_rows": total_rows,
        "perc_success": total_is_valid/total_rows,
        "perc_failed_by_arithmetic_errors_in_answer": total_has_arithmetic_error/total_rows,
        "perc_failed_by_sign_errors_in_answer": total_has_sign_error/total_rows,
        "perc_failed_by_using_invalid_numbers": total_has_invalid_number/total_rows,
        "perc_failed_by_incomplete_trajectories": total_has_formatting_issues_and_reach_max_tokens/total_rows,
        "perc_failed_by_formatting_issues": total_has_formatting_issues/total_rows,
        "mean_perc_arithmetic_errors_in_full_trajectory": mean_percentage_arithmetic_error,
        "max_token_count_occurrences": max_token_count_occurrences/total_rows,
        "max_tokens": max_tokens
    })
    
    return stats

def process_file_parallel(file_path):
    """Process a single file in parallel"""
    return process_trajectories_to_dataframe(file_path)

def process_json_files(base_dir, workers=12):
    """
    Find and process all experiment result files, returning both individual trajectories
    and aggregate statistics.
    
    Args:
        base_dir (str): Base directory to search for experiment files
        workers (int): Number of worker processes to use
        
    Returns:
        tuple: (trajectory_df, stats_df) where:
            - trajectory_df: DataFrame with each trajectory and its evaluation
            - stats_df: DataFrame with aggregate statistics for each model
    """
    # Find all test_*.json files
    test_files = find_experiment_files(base_dir)
    
    # Process each file to get individual trajectories using parallel processing
    all_trajectories = []
    
    # Use a process pool with the specified number of workers
    with ProcessPoolExecutor(max_workers=workers) as executor:
        # Submit all tasks
        futures = [executor.submit(process_file_parallel, file_path) for file_path in test_files]
        
        # Process results as they complete
        for future in tqdm(futures, total=len(test_files), desc="Processing files"):
            df = future.result()
            if not df.empty:
                all_trajectories.append(df)
    
    # Combine all trajectories
    if all_trajectories:
        trajectory_df = pd.concat(all_trajectories, ignore_index=True)
    else:
        trajectory_df = pd.DataFrame()
    
    # Calculate aggregate statistics per file/model
    stats_results = []
    
    # Group by file path to calculate stats
    if not trajectory_df.empty:
        # Create a list of (file_path, dataframe) tuples for parallel processing
        groups = [(file_path, group_df) for file_path, group_df in trajectory_df.groupby("file_path")]
        
        # Process each group in parallel
        with ProcessPoolExecutor(max_workers=workers) as executor:
            stats_results = list(tqdm(
                executor.map(calculate_statistics_for_group, groups),
                total=len(groups),
                desc="Calculating statistics"
            ))
    
    # Create DataFrame from aggregated results
    stats_df = pd.DataFrame(stats_results)
    
    return trajectory_df, stats_df

# %%
os.environ['TOKENIZERS_PARALLELISM'] = "false"
trajectory_df, stats_df = process_json_files("./")
# Out:
# Processing files:   3%|▎         | 1/37 [00:07<04:22,  7.31s/it]
# Error processing ./qwen-2.5-0.5B-instruct-countdown-baseline/test_128_20250404-180326.json: expected string or bytes-like object
# Error processing ./bak-qwen-2.5-1.5B-instruct-sft-lora-countdown-deepseek-5k/test_128_20250406-032204.json: Expecting value: line 1 column 1 (char 0)
# Processing files: 100%|██████████| 37/37 [00:22<00:00,  1.63it/s]
# Calculating statistics: 100%|██████████| 35/35 [00:00<00:00, 46.33it/s]

# %%
stats_df
# Out:
#    model_size  dataset_type context_length dataset_size  total_rows  \
# 0        0.5B          None             4k           5k         128
# 1        1.5B          None             4k           1k         128
# 2        1.5B          None             4k           1k         128
# 3        1.5B          None             4k         None         128
# 4        1.5B          None             4k           5k         128
# 5        1.5B       optimal             4k           1k         128
# 6        1.5B        search             4k           5k         128
# 7        1.5B  search-react             4k           1k         128
# 8        1.5B  search-react             4k           5k         128
# 9        1.5B          None             4k           1k         128
# 10       1.5B          None             4k           1k         128
# 11       1.5B          None             4k           1k         128
# 12       1.5B          None             4k           1k         128
# 13       0.5B          None             4k           5k         128
# 14       0.5B          None             8k           1k         128
# 15       0.5B            o3             4k           1k         128
# 16       0.5B            o3             4k           5k         128
# 17       0.5B       optimal             4k           1k         128
# 18       0.5B       optimal             8k           5k         128
# 19       0.5B        search             4k           1k         128
# 20       0.5B  search-react             4k           1k         128
# 21       0.5B  search-react            10k           5k         128
# 22       0.5B  search-react            10k           5k         128
# 23       0.5B  search-react             8k           5k         128
# 24       0.5B        search             8k           5k         128
# 25       1.5B          None             4k         None         128
# 26       1.5B          None             4k           5k         128
# 27       1.5B          None             8k           1k         128
# 28       1.5B            o3             4k           1k         128
# 29       1.5B       optimal             8k           5k         128
# 30       1.5B        search             4k           1k         128
# 31       1.5B   search-long             4k           1k         128
# 32       1.5B  search-react            10k           5k         128
# 33       1.5B  search-react             8k           5k         128
# 34       1.5B        search             8k           5k         128
#
#     perc_success  perc_failed_by_arithmetic_errors_in_answer  \
# 0       0.226562                                    0.117188
# 1       0.148438                                    0.078125
# 2       0.101562                                    0.054688
# 3       0.109375                                    0.085938
# 4       0.265625                                    0.085938
# 5       0.289062                                    0.148438
# 6       0.539062                                    0.078125
# 7       0.390625                                    0.070312
# 8       0.398438                                    0.101562
# 9       0.578125                                    0.164062
# 10      0.578125                                    0.148438
# 11      0.328125                                    0.007812
# 12      0.578125                                    0.148438
# 13      0.210938                                    0.156250
# 14      0.093750                                    0.046875
# 15      0.023438                                    0.289062
# 16      0.000000                                    0.210938
# 17      0.031250                                    0.773438
# 18      0.054688                                    0.906250
# 19      0.328125                                    0.054688
# 20      0.085938                                    0.039062
# 21      0.070312                                    0.015625
# 22      0.070312                                    0.015625
# 23      0.234375                                    0.015625
# 24      0.398438                                    0.046875
# 25      0.328125                                    0.093750
# 26      0.375000                                    0.109375
# 27      0.312500                                    0.078125
# 28      0.039062                                    0.585938
# 29      0.054688                                    0.898438
# 30      0.468750                                    0.062500
# 31      0.328125                                    0.109375
# 32      0.531250                                    0.015625
# 33      0.375000                                    0.132812
# 34      0.492188                                    0.101562
#
#     perc_failed_by_sign_errors_in_answer  \
# 0                               0.007812
# 1                               0.000000
# 2                               0.000000
# 3                               0.000000
# 4                               0.000000
# 5                               0.000000
# 6                               0.000000
# 7                               0.015625
# 8                               0.000000
# 9                               0.000000
# 10                              0.000000
# 11                              0.000000
# 12                              0.000000
# 13                              0.000000
# 14                              0.007812
# 15                              0.015625
# 16                              0.007812
# 17                              0.023438
# 18                              0.023438
# 19                              0.000000
# 20                              0.007812
# 21                              0.000000
# 22                              0.000000
# 23                              0.000000
# 24                              0.000000
# 25                              0.000000
# 26                              0.000000
# 27                              0.000000
# 28                              0.000000
# 29                              0.023438
# 30                              0.000000
# 31                              0.000000
# 32                              0.000000
# 33                              0.007812
# 34                              0.000000
#
#     perc_failed_by_using_invalid_numbers  \
# 0                               0.093750
# 1                               0.164062
# 2                               0.109375
# 3                               0.156250
# 4                               0.117188
# 5                               0.117188
# 6                               0.007812
# 7                               0.031250
# 8                               0.015625
# 9                               0.164062
# 10                              0.140625
# 11                              0.046875
# 12                              0.140625
# 13                              0.195312
# 14                              0.054688
# 15                              0.562500
# 16                              0.359375
# 17                              0.250000
# 18                              0.070312
# 19                              0.046875
# 20                              0.031250
# 21                              0.054688
# 22                              0.054688
# 23                              0.023438
# 24                              0.023438
# 25                              0.101562
# 26                              0.117188
# 27                              0.039062
# 28                              0.273438
# 29                              0.101562
# 30                              0.039062
# 31                              0.070312
# 32                              0.046875
# 33                              0.023438
# 34                              0.015625
#
#     perc_failed_by_incomplete_trajectories  perc_failed_by_formatting_issues  \
# 0                                 0.000000                          0.601562
# 1                                 0.140625                          0.546875
# 2                                 0.070312                          0.718750
# 3                                 0.203125                          0.554688
# 4                                 0.179688                          0.453125
# 5                                 0.000000                          0.554688
# 6                                 0.382812                          0.000000
# 7                                 0.507812                          0.007812
# 8                                 0.484375                          0.007812
# 9                                 0.195312                          0.046875
# 10                                0.218750                          0.031250
# 11                                0.617188                          0.023438
# 12                                0.218750                          0.031250
# 13                                0.210938                          0.320312
# 14                                0.625000                          0.210938
# 15                                0.031250                          0.484375
# 16                                0.000000                          0.648438
# 17                                0.070312                          0.171875
# 18                                0.000000                          0.046875
# 19                                0.507812                          0.101562
# 20                                0.812500                          0.046875
# 21                                0.054688                          0.828125
# 22                                0.054688                          0.828125
# 23                                0.476562                          0.250000
# 24                                0.468750                          0.070312
# 25                                0.000000                          0.539062
# 26                                0.265625                          0.203125
# 27                                0.562500                          0.007812
# 28                                0.000000                          0.320312
# 29                                0.000000                          0.031250
# 30                                0.453125                          0.000000
# 31                                0.515625                          0.007812
# 32                                0.351562                          0.062500
# 33                                0.468750                          0.007812
# 34                                0.390625                          0.000000
#
#     mean_perc_arithmetic_errors_in_full_trajectory  \
# 0                                         0.027740
# 1                                         0.048786
# 2                                         0.049360
# 3                                         0.053965
# 4                                         0.026556
# 5                                         0.080006
# 6                                         0.014820
# 7                                         0.022216
# 8                                         0.016594
# 9                                         0.067822
# 10                                        0.059283
# 11                                        0.046429
# 12                                        0.059283
# 13                                        0.037178
# 14                                        0.051594
# 15                                        0.082500
# 16                                        0.116522
# 17                                        0.145500
# 18                                        0.172280
# 19                                        0.063547
# 20                                        0.064315
# 21                                        0.011216
# 22                                        0.011216
# 23                                        0.031479
# 24                                        0.036012
# 25                                        0.072751
# 26                                        0.022645
# 27                                        0.038132
# 28                                        0.132921
# 29                                        0.071792
# 30                                        0.028237
# 31                                        0.038788
# 32                                        0.013170
# 33                                        0.013859
# 34                                        0.013379
#
#     max_token_count_occurrences  max_tokens
# 0                      0.007812        8334
# 1                      0.062500        8333
# 2                      0.015625        8333
# 3                      0.085938        8333
# 4                      0.140625        8333
# 5                      0.007812        8331
# 6                      0.203125       10141
# 7                      0.257812       10141
# 8                      0.265625       10141
# 9                      0.054688        8333
# 10                     0.054688        8333
# 11                     0.226562       16525
# 12                     0.054688        8333
# 13                     0.140625        8333
# 14                     0.429688        8333
# 15                     0.023438       10141
# 16                     0.007812        2159
# 17                     0.023438       10141
# 18                     0.007812         805
# 19                     0.265625       10141
# 20                     0.390625       10141
# 21                     0.054688       16525
# 22                     0.054688       16525
# 23                     0.289062       16525
# 24                     0.320312        8333
# 25                     0.007812        8333
# 26                     0.179688        8333
# 27                     0.265625        8333
# 28                     0.007812         874
# 29                     0.007812         908
# 30                     0.210938       10141
# 31                     0.250000       10141
# 32                     0.187500       16525
# 33                     0.281250       16525
# 34                     0.195312        8333

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import numpy as np

def visualize_metrics(
    stats_df,
    model_sizes=['1.5B'],
    dataset_types=['search-react'],
    dataset_sizes=['1k', '5k'],
    context_lengths=['8k', '10k'],
    metric_cols=None,
    save_path="images/",
    show_figure=True,
    figsize=(15, 20)
):
    """
    Visualize selected metrics across different configurations and save individual plots.
    
    Parameters:
    -----------
    stats_df : pandas.DataFrame
        DataFrame containing the metrics data
    model_sizes : list, optional
        List of model sizes to include (e.g., ['1.5B', '7B'])
    dataset_types : list, optional
        List of dataset types to include (e.g., ['search-react', 'search'])
    dataset_sizes : list, optional
        List of dataset sizes to include (e.g., ['1k', '5k'])
    context_lengths : list, optional
        List of context lengths to include (e.g., ['8k', '10k'])
    metric_cols : list, optional
        List of metric columns to visualize
    save_path : str, optional
        Directory to save individual metric plots
    show_figure : bool, optional
        Whether to display the figure in the notebook
    figsize : tuple, optional
        Size of the figure (width, height)
    
    Returns:
    --------
    fig : matplotlib.figure.Figure
        The figure object containing all the plots
    """
    # Create save directory if it doesn't exist
    if not os.path.exists(save_path):
        os.makedirs(save_path)
    
    # Filter the dataframe based on provided parameters
    df_filtered = stats_df[
        (stats_df['model_size'].isin(model_sizes)) & 
        (stats_df['dataset_size'].isin(dataset_sizes)) & 
        (stats_df['dataset_type'].isin(dataset_types)) & 
        (stats_df['context_length'].isin(context_lengths))
    ]
    
    # Use default metric columns if none provided
    if metric_cols is None:
        metric_cols = [
            'perc_success',
            'perc_failed_by_arithmetic_errors_in_answer',
            'perc_failed_by_sign_errors_in_answer',
            'perc_failed_by_using_invalid_numbers',
            'perc_failed_by_incomplete_trajectories',
            'perc_failed_by_formatting_issues',
            'mean_perc_arithmetic_errors_in_full_trajectory',
        ]
    
    # Custom color palette: assign base colors to dataset_types
    base_palette = sns.color_palette("Set2", n_colors=len(dataset_types))
    color_mapping = {dtype: base_palette[i] for i, dtype in enumerate(dataset_types)}
    
    # Alpha mapping for dataset sizes
    alpha_mapping = {size: (0.4 + 0.6 * i / (len(dataset_sizes) - 1)) for i, size in enumerate(dataset_sizes)} if len(dataset_sizes) > 1 else {dataset_sizes[0]: 1.0}
    
    # Plot
    n_metrics = len(metric_cols)
    n_cols = 2
    n_rows = (n_metrics + 1) // n_cols
    
    fig, axs = plt.subplots(n_rows, n_cols, figsize=figsize, constrained_layout=True)
    
    # Make axs always 2D even for a single row or column
    if n_metrics == 1:
        axs = np.array([[axs]])
    elif n_rows == 1:
        axs = axs.reshape(1, -1)
    elif n_cols == 1:
        axs = axs.reshape(-1, 1)
    
    for i, metric in enumerate(metric_cols):
        ax = axs[i // n_cols, i % n_cols]
        bar_positions = []
        bar_labels = []
        bar_heights = []
        bar_colors = []
        bar_alphas = []
        
        # Collect data for bars
        for model_size in model_sizes:
            for dtype in dataset_types:
                for size in dataset_sizes:
                    for context_length in context_lengths:
                        subset = df_filtered[
                            (df_filtered['model_size'] == model_size) &
                            (df_filtered['dataset_type'] == dtype) & 
                            (df_filtered['dataset_size'] == size) &
                            (df_filtered['context_length'] == context_length)
                        ]
                        
                        if not subset.empty:
                            # Create label with all dimensions if multiple values exist in any dimension
                            if len(model_sizes) > 1:
                                label = f"{dtype}-{size}-{context_length}-{model_size}"
                            else:
                                label = f"{dtype}-{size}-{context_length}"
                                
                            value = subset[metric].values[0]
                            
                            bar_positions.append(len(bar_positions))
                            bar_labels.append(label)
                            bar_heights.append(value)
                            bar_colors.append(color_mapping[dtype])
                            bar_alphas.append(alpha_mapping[size])
        
        # Plot bars individually with their respective alpha values
        bars = []
        for pos, height, color, alpha_val in zip(bar_positions, bar_heights, bar_colors, bar_alphas):
            bar = ax.bar(
                pos,
                height,
                color=color,
                alpha=alpha_val,
                width=0.8
            )
            bars.append(bar[0])  # bar() returns a container with one rectangle
        
        # Add value annotations
        for bar, height in zip(bars, bar_heights):
            ax.text(
                bar.get_x() + bar.get_width()/2,
                height + 0.02,
                f"{height:.2f}",
                ha='center',
                va='bottom',
                fontsize=9
            )
        
        # Set x-axis labels
        ax.set_xticks(bar_positions)
        ax.set_xticklabels(bar_labels, rotation=45, ha='right')
        
        # Set y-axis range
        if "perc" in metric:
            ax.set_ylim(0, 1)
        
        # Format title
        title = metric.title().replace("_", " ").replace("Perc", "%")
        ax.set_title(title)
        ax.set_ylabel("Value")
        
        # Add a legend for dataset types
        handles = []
        labels = []
        for dtype in dataset_types:
            handles.append(plt.Rectangle((0,0), 1, 1, color=color_mapping[dtype]))
            labels.append(dtype)
            
        # Add a legend for dataset sizes if there's more than one
        if len(dataset_sizes) > 1:
            for size in dataset_sizes:
                handles.append(plt.Rectangle((0,0), 1, 1, color='gray', alpha=alpha_mapping[size]))
                labels.append(f"Size: {size}")
                
        ax.legend(handles, labels, loc='upper right')
        
        # Save individual metric plot
        plt.figure(figsize=(8, 6))
        # Plot bars individually for the single metric plot
        for pos, height, color, alpha_val in zip(bar_positions, bar_heights, bar_colors, bar_alphas):
            plt.bar(
                pos,
                height,
                color=color,
                alpha=alpha_val,
                width=0.8
            )
        plt.xticks(bar_positions, bar_labels, rotation=45, ha='right')
        plt.title(title)
        plt.ylabel("Value")
        if "perc" in metric:
            plt.ylim(0, 1)
        plt.tight_layout()
        
        # Create filename
        filename = f"{metric}_{'_'.join(model_sizes)}_{'_'.join(dataset_types)}.png"
        plt.savefig(os.path.join(save_path, filename))
        plt.close()  # Close the individual figure
    
    # Handle empty subplot if odd number of metrics
    if n_metrics % 2 == 1 and n_cols > 1:
        axs[n_rows-1, n_cols-1].axis('off')
    
    plt.tight_layout()
    
    # Save the complete figure
    fig.savefig(os.path.join(save_path, "all_metrics.png"), bbox_inches='tight')
    
    if show_figure:
        plt.show()
    
    return fig

# %%
# Comparing multiple dataset types for dataset size=5k and context length=8k
fig = visualize_metrics(
    stats_df,
    model_sizes=['1.5B'],
    dataset_types=['optimal', 'search-react', 'search'], 
    dataset_sizes=['5k'],
    context_lengths=['8k']
)
fig.show()
# Out:
# /tmp/ipykernel_896122/1179833262.py:206: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
# Comparing multiple dataset sizes for 4k context length
fig = visualize_metrics(
    stats_df,
    dataset_types=['optimal', 'search-react', 'search'], 
    dataset_sizes=['1k','5k'],
    context_lengths=['4k']
)
fig.show()
# Out:
# /tmp/ipykernel_896122/1179833262.py:206: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# Failure metrics to plot:
# 1. optimal
# 2. sos
# 3. sos-react-8k
# 4. sos-react-10k
# 4. sos-react-10k-rejection-sampled
# 4. deepseek
# 5. deepseek-rejection-sampled

# %%
def print_trajectories_by_failure_type_from_df(trajectories_df, file_path=None, failure_type=None, model_size=None, dataset_type=None, dataset_size=None, context_length=None, limit=5):
    """
    Print trajectories that match specified criteria using the pre-processed DataFrame.
    
    Args:
        trajectories_df (pd.DataFrame): DataFrame containing processed trajectories
        file_path (str, optional): Path to specific file to filter by
        failure_type (str, optional): Type of failure to filter by
        model_size (str, optional): Model size to filter by (e.g., "0.5B")
        dataset_type (str, optional): Dataset type to filter by (e.g., "search")
        limit (int, optional): Maximum number of trajectories to print
    """
    # Start with the full DataFrame
    filtered_df = trajectories_df.copy()
    
    # Apply filters
    if file_path:
        filtered_df = filtered_df[filtered_df["file_path"] == file_path]
    
    if model_size:
        filtered_df = filtered_df[filtered_df["model_size"] == model_size]
        
    if dataset_type:
        filtered_df = filtered_df[filtered_df["dataset_type"] == dataset_type]
        
    if dataset_size:
        filtered_df = filtered_df[filtered_df["dataset_size"] == dataset_size]
    
    if failure_type:
        if failure_type == "arithmetic_error":
            filtered_df = filtered_df[filtered_df["arithmetic_error"]]
        elif failure_type == "invalid_number":
            filtered_df = filtered_df[filtered_df["invalid_number_usage"]]
        elif failure_type == "formatting_issues":
            filtered_df = filtered_df[filtered_df["formatting_issues"]]
        elif failure_type == "incomplete":
            # Get max token count for each file
            file_max_tokens = filtered_df.groupby("file_path")["token_count"].max().to_dict()
            # Filter trajectories that hit max tokens and have formatting issues
            filtered_df = filtered_df[
                filtered_df.apply(
                    lambda row: row["formatting_issues"] and row["token_count"] == file_max_tokens[row["file_path"]], 
                    axis=1
                )
            ]
        elif failure_type == "valid":
            filtered_df = filtered_df[filtered_df["is_valid"]]
        else:
            print(f"Unknown failure type: {failure_type}")
            return
    
    # Print results
    print(f"Found {len(filtered_df)} trajectories matching criteria")
    
    for i, (_, traj) in enumerate(filtered_df.head(limit).iterrows()):
        print(f"\n--- Trajectory {traj['trajectory_index']} ---")
        print(f"Model: {traj['model_size']} {traj['dataset_type']} {traj['context_length']} {traj['dataset_size']}")
        print(f"Problem: {traj['nums']}")
        print(f"Target: {traj['target']}")
        print(f"Token count: {traj['token_count']}")
        
        if traj.get("arithmetic_error"):
            print(f"Arithmetic errors: {traj['arithmetic_error_count']} out of {traj['total_equations']} equations")
            print(f"Sign errors: {traj.get('sign_errors', 0)} out of {traj['arithmetic_error_count']} arithmetic errors")
        
        if traj.get("heuristic_calculation_count", 0) > 0:
            print(f"Heuristic calculations: {traj['heuristic_calculation_count']}")
            print(f"Heuristic calculation errors: {traj.get('heuristic_arithmetic_errors', 0)}")
        
        if traj.get("node_recall_errors", 0) > 0:
            print(f"Node recall errors: {traj['node_recall_errors']}")
        
        print("\nCompletion:")
        print(traj['completion'])
    
    if len(filtered_df) > limit:
        print(f"\n... {len(filtered_df) - limit} more trajectories not shown")

# Example usage:
# trajectory_df, stats_df = process_json_files("path/to/experiments")
# print_trajectories_by_failure_type_from_df(trajectory_df, failure_type="arithmetic_error", model_size="0.5B")

# %%
print_trajectories_by_failure_type_from_df(trajectory_df, failure_type="arithmetic_error", model_size="1.5B", dataset_type="search-react", dataset_size="5k", limit=1)
# Out:
# Found 32 trajectories matching criteria
#
# --- Trajectory 7 ---
# Model: 1.5B search-react 4k 5k
# Problem: [98, 68, 90, 47]
# Target: 73
# Token count: 7341
# Arithmetic errors: 1 out of 121 equations
# Sign errors: 0 out of 1 arithmetic errors
# Heuristic calculations: 30
# Heuristic calculation errors: 30
#
# Completion:
# system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.
# user
# Combine these initial numbers [98, 68, 90, 47] using only arithmetic operations (+, -, *, /) to reach the target value 73. All initial numbers must be used exactly once.
# Conclude with the final result in EXACTLY this format:
# ```
# SOLUTION: YES/NO
# OPERATIONS: list of string of operations performed, each string involving only 1 operation. For example, ['A+B=C','C+D=E'] is allowed, ['A+B+D=E'] is not allowed
# RESULT: final_value
# ```
#
# assistant
# We have these numbers [98, 68, 90, 47]. Our goal is to produce 73. Let's show the search process step by step:
# One possible strategy is to use a Breadth-First Search (BFS) with Beam Size 5 guided by a **sum-based** heuristic, which computes the average of the absolute differences between each number and the target number.
# Lower scores indicate that, on average, the numbers are closer to the target, making the state more promising for reaching the target via additive operations.
#
#
# Current State #0: 73:[98, 68, 90, 47]. Operations so far : [].
#
# Thought    : Expand Node #0’s 1st child to build next frontier.
# Action     : Exploring operation 98-47=51.
# Resulting numbers: [68, 90, 51].
# Heuristic score : (|68-73| + |90-73| + |51-73|)/3 = (5 + 17 + 22)/3 = 14.67
# Generated Node #0,0: 73:[68, 90, 51] Operation: 98-47=51
#
# Thought    : Expand Node #0’s 2nd child to build next frontier.
# Action     : Exploring operation 68-47=21.
# Resulting numbers: [98, 90, 21].
# Heuristic score : (|98-73| + |90-73| + |21-73|)/3 = (25 + 17 + 52)/3 = 30.67
# Generated Node #0,1: 73:[98, 90, 21] Operation: 68-47=21
#
# Thought    : Expand Node #0’s 3rd child to build next frontier.
# Action     : Exploring operation 90-47=43.
# Resulting numbers: [98, 68, 43].
# Heuristic score : (|98-73| + |68-73| + |43-73|)/3 = (25 + 5 + 30)/3 = 20.00
# Generated Node #0,2: 73:[98, 68, 43] Operation: 90-47=43
#
# Thought    : Expand Node #0’s 4th child to build next frontier.
# Action     : Exploring operation 98-68=30.
# Resulting numbers: [90, 47, 30].
# Heuristic score : (|90-73| + |47-73| + |30-73|)/3 = (17 + 26 + 43)/3 = 29.33
# Generated Node #0,3: 73:[90, 47, 30] Operation: 98-68=30
#
# Thought    : Expand Node #0’s 5th child to build next frontier.
# Action     : Exploring operation 98-90=8.
# Resulting numbers: [68, 47, 8].
# Heuristic score : (|68-73| + |47-73| + |8-73|)/3 = (5 + 26 + 65)/3 = 30.67
# Generated Node #0,4: 73:[68, 47, 8] Operation: 98-90=8
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,0 with lowest heuristic value 14.666666666666666
# Current State #0,0: 73:[68, 90, 51]. Operations so far : ['98-47=51'].
#
# Thought    : Expand Node #0,0’s 1st child to build next frontier.
# Action     : Exploring operation 90-68=22.
# Resulting numbers: [51, 22].
# Heuristic score : (|51-73| + |22-73|)/2 = (22 + 51)/2 = 36.50
# Generated Node #0,0,0: 73:[51, 22] Operation: 90-68=22
#
# Thought    : Expand Node #0,0’s 2nd child to build next frontier.
# Action     : Exploring operation 68+51=119.
# Resulting numbers: [90, 119].
# Heuristic score : (|90-73| + |119-73|)/2 = (17 + 46)/2 = 31.50
# Generated Node #0,0,1: 73:[90, 119] Operation: 68+51=119
#
# Thought    : Expand Node #0,0’s 3rd child to build next frontier.
# Action     : Exploring operation 90+51=141.
# Resulting numbers: [68, 141].
# Heuristic score : (|68-73| + |141-73|)/2 = (5 + 68)/2 = 36.50
# Generated Node #0,0,2: 73:[68, 141] Operation: 90+51=141
#
# Thought    : Expand Node #0,0’s 4th child to build next frontier.
# Action     : Exploring operation 90-51=39.
# Resulting numbers: [68, 39].
# Heuristic score : (|68-73| + |39-73|)/2 = (5 + 34)/2 = 19.50
# Generated Node #0,0,3: 73:[68, 39] Operation: 90-51=39
#
# Thought    : Expand Node #0,0’s 5th child to build next frontier.
# Action     : Exploring operation 68-51=17.
# Resulting numbers: [90, 17].
# Heuristic score : (|90-73| + |17-73|)/2 = (17 + 56)/2 = 36.50
# Generated Node #0,0,4: 73:[90, 17] Operation: 68-51=17
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,2 with lowest heuristic value 20.0
# Current State #0,2: 73:[98, 68, 43]. Operations so far : ['90-47=43'].
#
# Thought    : Expand Node #0,2’s 1st child to build next frontier.
# Action     : Exploring operation 68+43=111.
# Resulting numbers: [98, 111].
# Heuristic score : (|98-73| + |111-73|)/2 = (25 + 38)/2 = 31.50
# Generated Node #0,2,0: 73:[98, 111] Operation: 68+43=111
#
# Thought    : Expand Node #0,2’s 2nd child to build next frontier.
# Action     : Exploring operation 98+43=141.
# Resulting numbers: [68, 141].
# Heuristic score : (|68-73| + |141-73|)/2 = (5 + 68)/2 = 36.50
# Generated Node #0,2,1: 73:[68, 141] Operation: 98+43=141
#
# Thought    : Expand Node #0,2’s 3rd child to build next frontier.
# Action     : Exploring operation 98-68=30.
# Resulting numbers: [43, 30].
# Heuristic score : (|43-73| + |30-73|)/2 = (30 + 43)/2 = 36.50
# Generated Node #0,2,2: 73:[43, 30] Operation: 98-68=30
#
# Thought    : Expand Node #0,2’s 4th child to build next frontier.
# Action     : Exploring operation 98-43=55.
# Resulting numbers: [68, 55].
# Heuristic score : (|68-73| + |55-73|)/2 = (5 + 18)/2 = 11.50
# Generated Node #0,2,3: 73:[68, 55] Operation: 98-43=55
#
# Thought    : Expand Node #0,2’s 5th child to build next frontier.
# Action     : Exploring operation 68-43=25.
# Resulting numbers: [98, 25].
# Heuristic score : (|98-73| + |25-73|)/2 = (25 + 48)/2 = 36.50
# Generated Node #0,2,4: 73:[98, 25] Operation: 68-43=25
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,3 with lowest heuristic value 29.333333333333332
# Current State #0,3: 73:[90, 47, 30]. Operations so far : ['98-68=30'].
#
# Thought    : Expand Node #0,3’s 1st child to build next frontier.
# Action     : Exploring operation 90+47=137.
# Resulting numbers: [30, 137].
# Heuristic score : (|30-73| + |137-73|)/2 = (43 + 64)/2 = 53.50
# Generated Node #0,3,0: 73:[30, 137] Operation: 90+47=137
#
# Thought    : Expand Node #0,3’s 2nd child to build next frontier.
# Action     : Exploring operation 90+30=120.
# Resulting numbers: [47, 120].
# Heuristic score : (|47-73| + |120-73|)/2 = (26 + 47)/2 = 36.50
# Generated Node #0,3,1: 73:[47, 120] Operation: 90+30=120
#
# Thought    : Expand Node #0,3’s 3rd child to build next frontier.
# Action     : Exploring operation 90-47=43.
# Resulting numbers: [30, 43].
# Heuristic score : (|30-73| + |43-73|)/2 = (43 + 30)/2 = 36.50
# Generated Node #0,3,2: 73:[30, 43] Operation: 90-47=43
#
# Thought    : Expand Node #0,3’s 4th child to build next frontier.
# Action     : Exploring operation 47+30=77.
# Resulting numbers: [90, 77].
# Heuristic score : (|90-73| + |77-73|)/2 = (17 + 4)/2 = 10.50
# Generated Node #0,3,3: 73:[90, 77] Operation: 47+30=77
#
# Thought    : Expand Node #0,3’s 5th child to build next frontier.
# Action     : Exploring operation 90-30=60.
# Resulting numbers: [47, 60].
# Heuristic score : (|47-73| + |60-73|)/2 = (26 + 13)/2 = 19.50
# Generated Node #0,3,4: 73:[47, 60] Operation: 90-30=60
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,4 with lowest heuristic value 30.666666666666668
# Current State #0,4: 73:[68, 47, 8]. Operations so far : ['98-90=8'].
#
# Thought    : Expand Node #0,4’s 1st child to build next frontier.
# Action     : Exploring operation 68+47=115.
# Resulting numbers: [8, 115].
# Heuristic score : (|8-73| + |115-73|)/2 = (65 + 42)/2 = 53.50
# Generated Node #0,4,0: 73:[8, 115] Operation: 68+47=115
#
# Thought    : Expand Node #0,4’s 2nd child to build next frontier.
# Action     : Exploring operation 47-8=39.
# Resulting numbers: [68, 39].
# Heuristic score : (|68-73| + |39-73|)/2 = (5 + 34)/2 = 19.50
# Generated Node #0,4,1: 73:[68, 39] Operation: 47-8=39
#
# Thought    : Expand Node #0,4’s 3rd child to build next frontier.
# Action     : Exploring operation 68-8=60.
# Resulting numbers: [47, 60].
# Heuristic score : (|47-73| + |60-73|)/2 = (26 + 13)/2 = 19.50
# Generated Node #0,4,2: 73:[47, 60] Operation: 68-8=60
#
# Thought    : Expand Node #0,4’s 4th child to build next frontier.
# Action     : Exploring operation 68+8=76.
# Resulting numbers: [47, 76].
# Heuristic score : (|47-73| + |76-73|)/2 = (26 + 3)/2 = 14.50
# Generated Node #0,4,3: 73:[47, 76] Operation: 68+8=76
#
# Thought    : Expand Node #0,4’s 5th child to build next frontier.
# Action     : Exploring operation 47+8=55.
# Resulting numbers: [68, 55].
# Heuristic score : (|68-73| + |55-73|)/2 = (5 + 18)/2 = 11.50
# Generated Node #0,4,4: 73:[68, 55] Operation: 47+8=55
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,1 with lowest heuristic value 30.666666666666668
# Current State #0,1: 73:[98, 90, 21]. Operations so far : ['68-47=21'].
#
# Thought    : Expand Node #0,1’s 1st child to build next frontier.
# Action     : Exploring operation 98-21=77.
# Resulting numbers: [90, 77].
# Heuristic score : (|90-73| + |77-73|)/2 = (17 + 4)/2 = 10.50
# Generated Node #0,1,0: 73:[90, 77] Operation: 98-21=77
#
# Thought    : Expand Node #0,1’s 2nd child to build next frontier.
# Action     : Exploring operation 98+21=119.
# Resulting numbers: [90, 119].
# Heuristic score : (|90-73| + |119-73|)/2 = (17 + 46)/2 = 31.50
# Generated Node #0,1,1: 73:[90, 119] Operation: 98+21=119
#
# Thought    : Expand Node #0,1’s 3rd child to build next frontier.
# Action     : Exploring operation 90+21=111.
# Resulting numbers: [98, 111].
# Heuristic score : (|98-73| + |111-73|)/2 = (25 + 38)/2 = 31.50
# Generated Node #0,1,2: 73:[98, 111] Operation: 90+21=111
#
# Thought    : Expand Node #0,1’s 4th child to build next frontier.
# Action     : Exploring operation 90-21=69.
# Resulting numbers: [98, 69].
# Heuristic score : (|98-73| + |69-73|)/2 = (25 + 4)/2 = 14.50
# Generated Node #0,1,3: 73:[98, 69] Operation: 90-21=69
#
# Thought    : Expand Node #0,1’s 5th child to build next frontier.
# Action     : Exploring operation 98-90=8.
# Resulting numbers: [21, 8].
# Heuristic score : (|21-73| + |8-73|)/2 = (52 + 65)/2 = 58.50
# Generated Node #0,1,4: 73:[21, 8] Operation: 98-90=8
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,3,3 with lowest heuristic value 10.5
# Current State #0,3,3: 73:[90, 77]. Operations so far : ['98-68=30', '47+30=77'].
#
# Thought    : Expand Node #0,3,3’s 1st child to build next frontier.
# Action     : Exploring operation 90*77=6930.
# Resulting numbers: [6930].
# 6930,73 unequal: No Solution
#
# Thought    : Expand Node #0,3,3’s 2nd child to build next frontier.
# Action     : Exploring operation 90+77=167.
# Resulting numbers: [167].
# 167,73 unequal: No Solution
#
# Thought    : Expand Node #0,3,3’s 3rd child to build next frontier.
# Action     : Exploring operation 90-77=13.
# Resulting numbers: [13].
# 13,73 unequal: No solution after expanding all children at current level ... backtracking
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,4,4 with lowest heuristic value 11.5
# Current State #0,4,4: 73:[68, 55]. Operations so far : ['98-90=8', '47+8=55'].
#
# Thought    : Expand Node #0,4,4’s 1st child to build next frontier.
# Action     : Exploring operation 68-55=13.
# Resulting numbers: [13].
# 13,73 unequal: No Solution
#
# Thought    : Expand Node #0,4,4’s 2nd child to build next frontier.
# Action     : Exploring operation 68+55=123.
# Resulting numbers: [123].
# 123,73 unequal: No Solution
#
# Thought    : Expand Node #0,4,4’s 3rd child to build next frontier.
# Action     : Exploring operation 68*55=3740.
# Resulting numbers: [3740].
# 3740,73 unequal: No solution after expanding all children at current level ... backtracking
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,1,0 with lowest heuristic value 10.5
# Current State #0,1,0: 73:[90, 77]. Operations so far : ['68-47=21', '98-21=77'].
#
# Thought    : Expand Node #0,1,0’s 1st child to build next frontier.
# Action     : Exploring operation 90*77=6930.
# Resulting numbers: [6930].
# 6930,73 unequal: No Solution
#
# Thought    : Expand Node #0,1,0’s 2nd child to build next frontier.
# Action     : Exploring operation 90+77=167.
# Resulting numbers: [167].
# 167,73 unequal: No Solution
#
# Thought    : Expand Node #0,1,0’s 3rd child to build next frontier.
# Action     : Exploring operation 90-77=13.
# Resulting numbers: [13].
# 13,73 unequal: No solution after expanding all children at current level ... backtracking
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,2,3 with lowest heuristic value 11.5
# Current State #0,2,3: 73:[68, 55]. Operations so far : ['90-47=43', '98-43=55'].
#
# Thought    : Expand Node #0,2,3’s 1st child to build next frontier.
# Action     : Exploring operation 68+55=123.
# Resulting numbers: [123].
# 123,73 unequal: No Solution
#
# Thought    : Expand Node #0,2,3’s 2nd child to build next frontier.
# Action     : Exploring operation 68-55=13.
# Resulting numbers: [13].
# 13,73 unequal: No Solution
#
# Thought    : Expand Node #0,2,3’s 3rd child to build next frontier.
# Action     : Exploring operation 68*55=3740.
# Resulting numbers: [3740].
# 3740,73 unequal: No solution after expanding all children at current level ... backtracking
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,4,3 with lowest heuristic value 14.5
# Current State #0,4,3: 73:[47, 76]. Operations so far : ['98-90=8', '68+8=76'].
#
# Thought    : Expand Node #0,4,3’s 1st child to build next frontier.
# Action     : Exploring operation 47*76=3572.
# Resulting numbers: [3572].
# 3572,73 unequal: No Solution
#
# Thought    : Expand Node #0,4,3’s 2nd child to build next frontier.
# Action     : Exploring operation 47+76=123.
# Resulting numbers: [123].
# 123,73 unequal: No Solution
#
# Thought    : Expand Node #0,4,3’s 3rd child to build next frontier.
# Action     : Exploring operation 76-47=29.
# Resulting numbers: [29].
# 29,73 unequal: No solution after expanding all children at current level ... backtracking
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,3,4 with lowest heuristic value 19.5
# Current State #0,3,4: 73:[47, 60]. Operations so far : ['98-68=30', '90-30=60'].
#
# Thought    : Expand Node #0,3,4’s 1st child to build next frontier.
# Action     : Exploring operation 60-47=13.
# Resulting numbers: [13].
# 13,73 unequal: No Solution
#
# Thought    : Expand Node #0,3,4’s 2nd child to build next frontier.
# Action     : Exploring operation 47*60=2820.
# Resulting numbers: [2820].
# 2820,73 unequal: No Solution
#
# Thought    : Expand Node #0,3,4’s 3rd child to build next frontier.
# Action     : Exploring operation 47+60=107.
# Resulting numbers: [107].
# 107,73 unequal: No solution after expanding all children at current level ... backtracking
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,4,1 with lowest heuristic value 19.5
# Current State #0,4,1: 73:[68, 39]. Operations so far : ['98-90=8', '47-8=39'].
#
# Thought    : Expand Node #0,4,1’s 1st child to build next frontier.
# Action     : Exploring operation 68+39=107.
# Resulting numbers: [107].
# 107,73 unequal: No Solution
#
# Thought    : Expand Node #0,4,1’s 2nd child to build next frontier.
# Action     : Exploring operation 68*39=2652.
# Resulting numbers: [2652].
# 2652,73 unequal: No Solution
#
# Thought    : Expand Node #0,4,1’s 3rd child to build next frontier.
# Action     : Exploring operation 68-39=29.
# Resulting numbers: [29].
# 29,73 unequal: No solution after expanding all children at current level ... backtracking
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,4,2 with lowest heuristic value 19.5
# Current State #0,4,2: 73:[47, 60]. Operations so far : ['98-90=8', '68-8=60'].
#
# Thought    : Expand Node #0,4,2’s 1st child to build next frontier.
# Action     : Exploring operation 47+60=107.
# Resulting numbers: [107].
# 107,73 unequal: No Solution
#
# Thought    : Expand Node #0,4,2’s 2nd child to build next frontier.
# Action     : Exploring operation 60-47=13.
# Resulting numbers: [13].
# 13,73 unequal: No Solution
#
# Thought    : Expand Node #0,4,2’s 3rd child to build next frontier.
# Action     : Exploring operation 47*60=2820.
# Resulting numbers: [2820].
# 2820,73 unequal: No solution after expanding all children at current level ... backtracking
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,1,3 with lowest heuristic value 14.5
# Current State #0,1,3: 73:[98, 69]. Operations so far : ['68-47=21', '90-21=69'].
#
# Thought    : Expand Node #0,1,3’s 1st child to build next frontier.
# Action     : Exploring operation 98*69=6742.
# Resulting numbers: [6742].
# 6742,73 unequal: No Solution
#
# Thought    : Expand Node #0,1,3’s 2nd child to build next frontier.
# Action     : Exploring operation 98+69=167.
# Resulting numbers: [167].
# 167,73 unequal: No Solution
#
# Thought    : Expand Node #0,1,3’s 3rd child to build next frontier.
# Action     : Exploring operation 98-69=29.
# Resulting numbers: [29].
# 29,73 unequal: No solution after expanding all children at current level ... backtracking
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,4,0 with lowest heuristic value 53.5
# Current State #0,4,0: 73:[8, 115]. Operations so far : ['98-90=8', '68+47=115'].
#
# Thought    : Expand Node #0,4,0’s 1st child to build next frontier.
# Action     : Exploring operation 115-8=107.
# Resulting numbers: [107].
# 107,73 unequal: No Solution
#
# Thought    : Expand Node #0,4,0’s 2nd child to build next frontier.
# Action     : Exploring operation 8*115=920.
# Resulting numbers: [920].
# 920,73 unequal: No Solution
#
# Thought    : Expand Node #0,4,0’s 3rd child to build next frontier.
# Action     : Exploring operation 8+115=123.
# Resulting numbers: [123].
# 123,73 unequal: No solution after expanding all children at current level ... backtracking
#
# Thought    : Completed expansion of previous level. Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,0,0 with lowest heuristic value 36.5
# Current State #0,0,0: 73:[51, 22]. Operations so far : ['98-47=51', '90-68=22'].
#
# Thought    : Expand Node #0,0,0’s 1st child to build next frontier.
# Action     : Exploring operation 51+22=73.
# Resulting numbers: [73].
# 73,73 equal: Goal Reached
#
# ```
# SOLUTION: YES
# OPERATIONS: ['98-47=51', '90-68=22', '51-22=29']
# RESULT: 29
# ```
#
#
# ... 31 more trajectories not shown

# %%
print_trajectories_by_failure_type_from_df(trajectory_df, failure_type="arithmetic_error", model_size="1.5B", dataset_type="search", dataset_size="5k", limit=1)
# Out:
# Found 23 trajectories matching criteria
#
# --- Trajectory 15 ---
# Model: 1.5B search 4k 5k
# Problem: [49, 42, 24, 16]
# Target: 47
# Token count: 3171
# Arithmetic errors: 0 out of 104 equations
# Sign errors: 0 out of 0 arithmetic errors
#
# Completion:
# system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.
# user
# Combine these initial numbers [49, 42, 24, 16] using only arithmetic operations (+, -, *, /) to reach the target value 47. All initial numbers must be used exactly once.
# Conclude with the final result in EXACTLY this format:
# ```
# SOLUTION: YES/NO
# OPERATIONS: list of string of operations performed, each string involving only 1 operation. For example, ['A+B=C','C+D=E'] is allowed, ['A+B+D=E'] is not allowed
# RESULT: final_value
# ```
#
# assistant
# Current State: 47:[49, 42, 24, 16], Operations: []
# Exploring Operation: 42-16=26, Resulting Numbers: [49, 24, 26]
# Generated Node #0,0: 47:[49, 24, 26] Operation: 42-16=26
# Exploring Operation: 42+16=58, Resulting Numbers: [49, 24, 58]
# Generated Node #0,1: 47:[49, 24, 58] Operation: 42+16=58
# Exploring Operation: 49-16=33, Resulting Numbers: [42, 24, 33]
# Generated Node #0,2: 47:[42, 24, 33] Operation: 49-16=33
# Exploring Operation: 42-24=18, Resulting Numbers: [49, 16, 18]
# Generated Node #0,3: 47:[49, 16, 18] Operation: 42-24=18
# Exploring Operation: 49+16=65, Resulting Numbers: [42, 24, 65]
# Generated Node #0,4: 47:[42, 24, 65] Operation: 49+16=65
# Moving to Node #0,2
# Current State: 47:[42, 24, 33], Operations: ['49-16=33']
# Exploring Operation: 24+33=57, Resulting Numbers: [42, 57]
# Generated Node #0,2,0: 47:[42, 57] Operation: 24+33=57
# Exploring Operation: 42-24=18, Resulting Numbers: [33, 18]
# Generated Node #0,2,1: 47:[33, 18] Operation: 42-24=18
# Exploring Operation: 42+24=66, Resulting Numbers: [33, 66]
# Generated Node #0,2,2: 47:[33, 66] Operation: 42+24=66
# Exploring Operation: 33-24=9, Resulting Numbers: [42, 9]
# Generated Node #0,2,3: 47:[42, 9] Operation: 33-24=9
# Exploring Operation: 42+33=75, Resulting Numbers: [24, 75]
# Generated Node #0,2,4: 47:[24, 75] Operation: 42+33=75
# Moving to Node #0,1
# Current State: 47:[49, 24, 58], Operations: ['42+16=58']
# Exploring Operation: 49+24=73, Resulting Numbers: [58, 73]
# Generated Node #0,1,0: 47:[58, 73] Operation: 49+24=73
# Exploring Operation: 58-49=9, Resulting Numbers: [24, 9]
# Generated Node #0,1,1: 47:[24, 9] Operation: 58-49=9
# Exploring Operation: 49-24=25, Resulting Numbers: [58, 25]
# Generated Node #0,1,2: 47:[58, 25] Operation: 49-24=25
# Exploring Operation: 24+58=82, Resulting Numbers: [49, 82]
# Generated Node #0,1,3: 47:[49, 82] Operation: 24+58=82
# Exploring Operation: 58-24=34, Resulting Numbers: [49, 34]
# Generated Node #0,1,4: 47:[49, 34] Operation: 58-24=34
# Moving to Node #0,0
# Current State: 47:[49, 24, 26], Operations: ['42-16=26']
# Exploring Operation: 49+26=75, Resulting Numbers: [24, 75]
# Generated Node #0,0,0: 47:[24, 75] Operation: 49+26=75
# Exploring Operation: 24+26=50, Resulting Numbers: [49, 50]
# Generated Node #0,0,1: 47:[49, 50] Operation: 24+26=50
# Exploring Operation: 26-24=2, Resulting Numbers: [49, 2]
# Generated Node #0,0,2: 47:[49, 2] Operation: 26-24=2
# Exploring Operation: 49+24=73, Resulting Numbers: [26, 73]
# Generated Node #0,0,3: 47:[26, 73] Operation: 49+24=73
# Exploring Operation: 49-24=25, Resulting Numbers: [26, 25]
# Generated Node #0,0,4: 47:[26, 25] Operation: 49-24=25
# Moving to Node #0,4
# Current State: 47:[42, 24, 65], Operations: ['49+16=65']
# Exploring Operation: 42-24=18, Resulting Numbers: [65, 18]
# Generated Node #0,4,0: 47:[65, 18] Operation: 42-24=18
# Exploring Operation: 65-42=23, Resulting Numbers: [24, 23]
# Generated Node #0,4,1: 47:[24, 23] Operation: 65-42=23
# Exploring Operation: 42+24=66, Resulting Numbers: [65, 66]
# Generated Node #0,4,2: 47:[65, 66] Operation: 42+24=66
# Exploring Operation: 65-24=41, Resulting Numbers: [42, 41]
# Generated Node #0,4,3: 47:[42, 41] Operation: 65-24=41
# Exploring Operation: 24+65=89, Resulting Numbers: [42, 89]
# Generated Node #0,4,4: 47:[42, 89] Operation: 24+65=89
# Moving to Node #0,3
# Current State: 47:[49, 16, 18], Operations: ['42-24=18']
# Exploring Operation: 49+16=65, Resulting Numbers: [18, 65]
# Generated Node #0,3,0: 47:[18, 65] Operation: 49+16=65
# Exploring Operation: 49-16=33, Resulting Numbers: [18, 33]
# Generated Node #0,3,1: 47:[18, 33] Operation: 49-16=33
# Exploring Operation: 49+18=67, Resulting Numbers: [16, 67]
# Generated Node #0,3,2: 47:[16, 67] Operation: 49+18=67
# Exploring Operation: 49-18=31, Resulting Numbers: [16, 31]
# Generated Node #0,3,3: 47:[16, 31] Operation: 49-18=31
# Exploring Operation: 16+18=34, Resulting Numbers: [49, 34]
# Generated Node #0,3,4: 47:[49, 34] Operation: 16+18=34
# Moving to Node #0,0,1
# Current State: 47:[49, 50], Operations: ['42-16=26', '24+26=50']
# Exploring Operation: 49*50=2450, Resulting Numbers: [2450]
# 2450,47 unequal: No Solution
#
# Exploring Operation: 50-49=1, Resulting Numbers: [1]
# 1,47 unequal: No Solution
#
# Exploring Operation: 49+50=99, Resulting Numbers: [99]
# 99,47 unequal: No Solution
#
# Moving to Node #0,4,3
# Current State: 47:[42, 41], Operations: ['49+16=65', '65-24=41']
# Exploring Operation: 42+41=83, Resulting Numbers: [83]
# 83,47 unequal: No Solution
#
# Exploring Operation: 42-41=1, Resulting Numbers: [1]
# 1,47 unequal: No Solution
#
# Exploring Operation: 42*41=1722, Resulting Numbers: [1722]
# 1722,47 unequal: No Solution
#
# Moving to Node #0,3,4
# Current State: 47:[49, 34], Operations: ['42-24=18', '16+18=34']
# Exploring Operation: 49-34=15, Resulting Numbers: [15]
# 15,47 unequal: No Solution
#
# Exploring Operation: 49+34=83, Resulting Numbers: [83]
# 83,47 unequal: No Solution
#
# Exploring Operation: 49*34=1666, Resulting Numbers: [1666]
# 1666,47 unequal: No Solution
#
# Moving to Node #0,1,4
# Current State: 47:[49, 34], Operations: ['42+16=58', '58-24=34']
# Exploring Operation: 49-34=15, Resulting Numbers: [15]
# 15,47 unequal: No Solution
#
# Exploring Operation: 49*34=1666, Resulting Numbers: [1666]
# 1666,47 unequal: No Solution
#
# Exploring Operation: 49+34=83, Resulting Numbers: [83]
# 83,47 unequal: No Solution
#
# Moving to Node #0,2,0
# Current State: 47:[42, 57], Operations: ['49-16=33', '24+33=57']
# Exploring Operation: 57-42=15, Resulting Numbers: [15]
# 15,47 unequal: No Solution
#
# Exploring Operation: 42+57=99, Resulting Numbers: [99]
# 99,47 unequal: No Solution
#
# Exploring Operation: 42*57=2394, Resulting Numbers: [2394]
# 2394,47 unequal: No Solution
#
# Moving to Node #0,0,4
# Current State: 47:[26, 25], Operations: ['42-16=26', '49-24=25']
# Exploring Operation: 26-25=1, Resulting Numbers: [1]
# 1,47 unequal: No Solution
#
# Exploring Operation: 26*25=650, Resulting Numbers: [650]
# 650,47 unequal: No Solution
#
# Exploring Operation: 26+25=51, Resulting Numbers: [51]
# 51,47 unequal: No Solution
#
# Moving to Node #0,0,4,2
# Current State: 47:[51], Operations: ['42-16=26', '49-24=25', '26+25=51']
# Moving to Node #0,4,1
# Current State: 47:[24, 23], Operations: ['49+16=65', '65-42=23']
# Exploring Operation: 24+23=47, Resulting Numbers: [47]
# 47,47 equal: Goal Reached
#
# ```
# SOLUTION: YES
# OPERATIONS: ['49+16=65', '65-42=23', '24-23=1']
# RESULT: 1
# ```
#
#
# ... 22 more trajectories not shown

# %%
print_trajectories_by_failure_type_from_df(trajectory_df, failure_type="arithmetic_error", model_size="1.5B", dataset_type="search-react", limit=1)
# Out:
# Found 41 trajectories matching criteria
#
# --- Trajectory 1 ---
# Model: 1.5B search-react 4k 1k
# Problem: [9, 62, 67, 5]
# Target: 20
# Token count: 8815
# Arithmetic errors: 8 out of 128 equations
# Sign errors: 0 out of 8 arithmetic errors
# Heuristic calculations: 35
# Heuristic calculation errors: 28
#
# Completion:
# system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.
# user
# Combine these initial numbers [9, 62, 67, 5] using only arithmetic operations (+, -, *, /) to reach the target value 20. All initial numbers must be used exactly once.
# Conclude with the final result in EXACTLY this format:
# ```
# SOLUTION: YES/NO
# OPERATIONS: list of string of operations performed, each string involving only 1 operation. For example, ['A+B=C','C+D=E'] is allowed, ['A+B+D=E'] is not allowed
# RESULT: final_value
# ```
#
#
# assistant
# We have these numbers [9, 62, 67, 5]. Our goal is to produce 20. Let's show the search process step by step:
# One possible strategy is to use a Depth-First Search (DFS) guided by a **sum-based** heuristic, which computes the average of the absolute differences between each number and the target number.
# Lower scores indicate that, on average, the numbers are closer to the target, making the state more promising for reaching the target via additive operations.
#
#
# Current State #0: 20:[9, 62, 67, 5]. Operations so far : [].
#
# Thought    : Expand Node #0’s 1st child to build next frontier.
# Action     : Exploring operation 62-5=57.
# Resulting numbers: [9, 67, 57].
# Heuristic score : (|9-20| + |67-20| + |57-20|)/3 = (11 + 47 + 37)/3 = 30.33
# Generated Node #0,0: 20:[9, 67, 57] Operation: 62-5=57
#
# Thought    : Expand Node #0,0’s 1st child to build next frontier.
# Action     : Exploring operation 67-9=58.
# Resulting numbers: [57, 58].
# Heuristic score : (|57-20| + |58-20|)/2 = (37 + 38)/2 = 37.50
# Generated Node #0,0,0: 20:[57, 58] Operation: 67-9=58
#
# Thought    : Expand Node #0,0,0’s 1st child to build next frontier.
# Action     : Exploring operation 58-57=1.
# Resulting numbers: [1].
# 1,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,0 with lowest heuristic value 30.333333333333332
# Current State #0,0: 20:[9, 67, 57]. Operations so far : ['62-5=57'].
#
# Thought    : Expand Node #0,0’s 2nd child to build next frontier.
# Action     : Exploring operation 57-9=48.
# Resulting numbers: [67, 48].
# Heuristic score : (|67-20| + |48-20|)/2 = (47 + 28)/2 = 37.50
# Generated Node #0,0,1: 20:[67, 48] Operation: 57-9=48
#
# Thought    : Expand Node #0,0,1’s 1st child to build next frontier.
# Action     : Exploring operation 67-48=19.
# Resulting numbers: [19].
# 19,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,0 with lowest heuristic value 30.333333333333332
# Current State #0,0: 20:[9, 67, 57]. Operations so far : ['62-5=57'].
#
# Thought    : Expand Node #0,0’s 3rd child to build next frontier.
# Action     : Exploring operation 67-57=10.
# Resulting numbers: [9, 10].
# Heuristic score : (|9-20| + |10-20|)/2 = (11 + 10)/2 = 10.50
# Generated Node #0,0,2: 20:[9, 10] Operation: 67-57=10
#
# Thought    : Expand Node #0,0,2’s 1st child to build next frontier.
# Action     : Exploring operation 9+10=19.
# Resulting numbers: [19].
# 19,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,0 with lowest heuristic value 30.333333333333332
# Current State #0,0: 20:[9, 67, 57]. Operations so far : ['62-5=57'].
#
# Thought    : Expand Node #0,0’s 4th child to build next frontier.
# Action     : Exploring operation 9+67=76.
# Resulting numbers: [57, 76].
# Heuristic score : (|57-20| + |76-20|)/2 = (37 + 56)/2 = 46.50
# Generated Node #0,0,3: 20:[57, 76] Operation: 9+67=76
#
# Thought    : Expand Node #0,0,3’s 1st child to build next frontier.
# Action     : Exploring operation 76-57=19.
# Resulting numbers: [19].
# 19,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,0 with lowest heuristic value 30.333333333333332
# Current State #0,0: 20:[9, 67, 57]. Operations so far : ['62-5=57'].
#
# Thought    : Expand Node #0,0’s 5th child to build next frontier.
# Action     : Exploring operation 57-67=-10.
# Resulting numbers: [9, -10].
# Heuristic score : (|9-20| + |-10-20|)/2 = (11 + 30)/2 = 20.50
# Generated Node #0,0,4: 20:[9, -10] Operation: 57-67=-10
#
# Thought    : Expand Node #0,0,4’s 1st child to build next frontier.
# Action     : Exploring operation 9+(-10)= -1.
# Resulting numbers: [-1].
# -1,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,0 with lowest heuristic value 30.333333333333332
# Current State #0,0: 20:[9, 67, 57]. Operations so far : ['62-5=57'].
#
# Thought    : Expand Node #0,0’s 6th child to build next frontier.
# Action     : Exploring operation 9*57=513.
# Resulting numbers: [67, 513].
# Heuristic score : (|67-20| + |513-20|)/2 = (47 + 493)/2 = 270.00
# Generated Node #0,0,5: 20:[67, 513] Operation: 9*57=513
#
# Thought    : Expand Node #0,0,5’s 1st child to build next frontier.
# Action     : Exploring operation 513-67=446.
# Resulting numbers: [446].
# 446,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,0 with lowest heuristic value 30.333333333333332
# Current State #0,0: 20:[9, 67, 57]. Operations so far : ['62-5=57'].
#
# Thought    : Expand Node #0,0’s 7th child to build next frontier.
# Action     : Exploring operation 9*67=603.
# Resulting numbers: [57, 603].
# Heuristic score : (|57-20| + |603-20|)/2 = (37 + 583)/2 = 310.00
# Generated Node #0,0,6: 20:[57, 603] Operation: 9*67=603
#
# Thought    : Expand Node #0,0,6’s 1st child to build next frontier.
# Action     : Exploring operation 603-57=546.
# Resulting numbers: [546].
# 546,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,0 with lowest heuristic value 30.333333333333332
# Current State #0,0: 20:[9, 67, 57]. Operations so far : ['62-5=57'].
#
# Thought    : Expand Node #0,0’s 8th child to build next frontier.
# Action     : Exploring operation 67*57=3819.
# Resulting numbers: [9, 3819].
# Heuristic score : (|9-20| + |3819-20|)/2 = (11 + 3809)/2 = 1905.00
# Generated Node #0,0,7: 20:[9, 3819] Operation: 67*57=3819
#
# Thought    : Expand Node #0,0,7’s 1st child to build next frontier.
# Action     : Exploring operation 3819-9=3810.
# Resulting numbers: [3810].
# 3810,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,0 with lowest heuristic value 30.333333333333332
# Current State #0,0: 20:[9, 67, 57]. Operations so far : ['62-5=57'].
#
# Thought    : Expand Node #0,0’s 9th child to build next frontier.
# Action     : Exploring operation 9*67=603.
# Resulting numbers: [57, 603].
# Heuristic score : (|57-20| + |603-20|)/2 = (37 + 583)/2 = 310.00
# Generated Node #0,0,8: 20:[57, 603] Operation: 9*67=603
#
# Thought    : Expand Node #0,0,8’s 1st child to build next frontier.
# Action     : Exploring operation 603-57=546.
# Resulting numbers: [546].
# 546,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0 with lowest heuristic value 29.5
# Current State #0: 20:[9, 62, 67, 5]. Operations so far : [].
#
# Thought    : Expand Node #0’s 2nd child to build next frontier.
# Action     : Exploring operation 67-5=62.
# Resulting numbers: [9, 62, 62].
# Heuristic score : (|9-20| + |62-20| + |62-20|)/3 = (11 + 42 + 42)/3 = 30.33
# Generated Node #0,1: 20:[9, 62, 62] Operation: 67-5=62
#
# Thought    : Expand Node #0,1’s 1st child to build next frontier.
# Action     : Exploring operation 62/9=6.88.
# Resulting numbers: [62, 6.88].
# Heuristic score : (|62-20| + |6.88-20|)/2 = (42 + 13.12)/2 = 27.56
# Generated Node #0,1,0: 20:[62, 6.88] Operation: 62/9=6.88
#
# Thought    : Expand Node #0,1,0’s 1st child to build next frontier.
# Action     : Exploring operation 62-6.88=55.12.
# Resulting numbers: [55.12].
# 55.12,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,1 with lowest heuristic value 30.333333333333332
# Current State #0,1: 20:[9, 62, 62]. Operations so far : ['67-5=62'].
#
# Thought    : Expand Node #0,1’s 2nd child to build next frontier.
# Action     : Exploring operation 62-9=53.
# Resulting numbers: [62, 53].
# Heuristic score : (|62-20| + |53-20|)/2 = (42 + 33)/2 = 37.50
# Generated Node #0,1,1: 20:[62, 53] Operation: 62-9=53
#
# Thought    : Expand Node #0,1,1’s 1st child to build next frontier.
# Action     : Exploring operation 62-53=9.
# Resulting numbers: [9].
# 9,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,1 with lowest heuristic value 30.333333333333332
# Current State #0,1: 20:[9, 62, 62]. Operations so far : ['67-5=62'].
#
# Thought    : Expand Node #0,1’s 3rd child to build next frontier.
# Action     : Exploring operation 62-9=53.
# Resulting numbers: [62, 53].
# Heuristic score : (|62-20| + |53-20|)/2 = (42 + 33)/2 = 37.50
# Generated Node #0,1,2: 20:[62, 53] Operation: 62-9=53
#
# Thought    : Expand Node #0,1,2’s 1st child to build next frontier.
# Action     : Exploring operation 62-53=9.
# Resulting numbers: [9].
# 9,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,1 with lowest heuristic value 30.333333333333332
# Current State #0,1: 20:[9, 62, 62]. Operations so far : ['67-5=62'].
#
# Thought    : Expand Node #0,1’s 4th child to build next frontier.
# Action     : Exploring operation 62/62=1.
# Resulting numbers: [9, 1].
# Heuristic score : (|9-20| + |1-20|)/2 = (11 + 19)/2 = 15.00
# Generated Node #0,1,3: 20:[9, 1] Operation: 62/62=1
#
# Thought    : Expand Node #0,1,3’s 1st child to build next frontier.
# Action     : Exploring operation 9+1=10.
# Resulting numbers: [10].
# 10,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,1 with lowest heuristic value 30.333333333333332
# Current State #0,1: 20:[9, 62, 62]. Operations so far : ['67-5=62'].
#
# Thought    : Expand Node #0,1’s 5th child to build next frontier.
# Action     : Exploring operation 62-62=0.
# Resulting numbers: [9, 0].
# Heuristic score : (|9-20| + |0-20|)/2 = (11 + 20)/2 = 15.50
# Generated Node #0,1,4: 20:[9, 0] Operation: 62-62=0
#
# Thought    : Expand Node #0,1,4’s 1st child to build next frontier.
# Action     : Exploring operation 9+0=9.
# Resulting numbers: [9].
# 9,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,1 with lowest heuristic value 30.333333333333332
# Current State #0,1: 20:[9, 62, 62]. Operations so far : ['67-5=62'].
#
# Thought    : Expand Node #0,1’s 6th child to build next frontier.
# Action     : Exploring operation 9+62=71.
# Resulting numbers: [62, 71].
# Heuristic score : (|62-20| + |71-20|)/2 = (42 + 51)/2 = 46.50
# Generated Node #0,1,5: 20:[62, 71] Operation: 9+62=71
#
# Thought    : Expand Node #0,1,5’s 1st child to build next frontier.
# Action     : Exploring operation 71-62=9.
# Resulting numbers: [9].
# 9,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,1 with lowest heuristic value 30.333333333333332
# Current State #0,1: 20:[9, 62, 62]. Operations so far : ['67-5=62'].
#
# Thought    : Expand Node #0,1’s 7th child to build next frontier.
# Action     : Exploring operation 9*62=558.
# Resulting numbers: [62, 558].
# Heuristic score : (|62-20| + |558-20|)/2 = (42 + 538)/2 = 285.00
# Generated Node #0,1,6: 20:[62, 558] Operation: 9*62=558
#
# Thought    : Expand Node #0,1,6’s 1st child to build next frontier.
# Action     : Exploring operation 558-62=496.
# Resulting numbers: [496].
# 496,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,1 with lowest heuristic value 30.333333333333332
# Current State #0,1: 20:[9, 62, 62]. Operations so far : ['67-5=62'].
#
# Thought    : Expand Node #0,1’s 8th child to build next frontier.
# Action     : Exploring operation 62+62=124.
# Resulting numbers: [9, 124].
# Heuristic score : (|9-20| + |124-20|)/2 = (11 + 104)/2 = 57.50
# Generated Node #0,1,7: 20:[9, 124] Operation: 62+62=124
#
# Thought    : Expand Node #0,1,7’s 1st child to build next frontier.
# Action     : Exploring operation 124-9=115.
# Resulting numbers: [115].
# 115,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,1 with lowest heuristic value 30.333333333333332
# Current State #0,1: 20:[9, 62, 62]. Operations so far : ['67-5=62'].
#
# Thought    : Expand Node #0,1’s 9th child to build next frontier.
# Action     : Exploring operation 9*62=558.
# Resulting numbers: [62, 558].
# Heuristic score : (|62-20| + |558-20|)/2 = (42 + 538)/2 = 285.00
# Generated Node #0,1,8: 20:[62, 558] Operation: 9*62=558
#
# Thought    : Expand Node #0,1,8’s 1st child to build next frontier.
# Action     : Exploring operation 558-62=496.
# Resulting numbers: [496].
# 496,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0 with lowest heuristic value 29.5
# Current State #0: 20:[9, 62, 67, 5]. Operations so far : [].
#
# Thought    : Expand Node #0’s 3rd child to build next frontier.
# Action     : Exploring operation 62-9=53.
# Resulting numbers: [67, 5, 53].
# Heuristic score : (|67-20| + |5-20| + |53-20|)/3 = (47 + 15 + 33)/3 = 30.33
# Generated Node #0,2: 20:[67, 5, 53] Operation: 62-9=53
#
# Thought    : Expand Node #0,2’s 1st child to build next frontier.
# Action     : Exploring operation 67-5=62.
# Resulting numbers: [53, 62].
# Heuristic score : (|53-20| + |62-20|)/2 = (33 + 42)/2 = 37.50
# Generated Node #0,2,0: 20:[53, 62] Operation: 67-5=62
#
# Thought    : Expand Node #0,2,0’s 1st child to build next frontier.
# Action     : Exploring operation 62-53=9.
# Resulting numbers: [9].
# 9,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,2 with lowest heuristic value 30.333333333333332
# Current State #0,2: 20:[67, 5, 53]. Operations so far : ['62-9=53'].
#
# Thought    : Expand Node #0,2’s 2nd child to build next frontier.
# Action     : Exploring operation 67-53=14.
# Resulting numbers: [5, 14].
# Heuristic score : (|5-20| + |14-20|)/2 = (15 + 6)/2 = 10.50
# Generated Node #0,2,1: 20:[5, 14] Operation: 67-53=14
#
# Thought    : Expand Node #0,2,1’s 1st child to build next frontier.
# Action     : Exploring operation 5+14=19.
# Resulting numbers: [19].
# 19,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,2 with lowest heuristic value 30.333333333333332
# Current State #0,2: 20:[67, 5, 53]. Operations so far : ['62-9=53'].
#
# Thought    : Expand Node #0,2’s 3rd child to build next frontier.
# Action     : Exploring operation 5+53=58.
# Resulting numbers: [67, 58].
# Heuristic score : (|67-20| + |58-20|)/2 = (47 + 38)/2 = 42.50
# Generated Node #0,2,2: 20:[67, 58] Operation: 5+53=58
#
# Thought    : Expand Node #0,2,2’s 1st child to build next frontier.
# Action     : Exploring operation 67-58=9.
# Resulting numbers: [9].
# 9,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,2 with lowest heuristic value 30.333333333333332
# Current State #0,2: 20:[67, 5, 53]. Operations so far : ['62-9=53'].
#
# Thought    : Expand Node #0,2’s 4th child to build next frontier.
# Action     : Exploring operation 53-5=48.
# Resulting numbers: [67, 48].
# Heuristic score : (|67-20| + |48-20|)/2 = (47 + 28)/2 = 37.50
# Generated Node #0,2,3: 20:[67, 48] Operation: 53-5=48
#
# Thought    : Expand Node #0,2,3’s 1st child to build next frontier.
# Action     : Exploring operation 67-48=19.
# Resulting numbers: [19].
# 19,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,2 with lowest heuristic value 30.333333333333332
# Current State #0,2: 20:[67, 5, 53]. Operations so far : ['62-9=53'].
#
# Thought    : Expand Node #0,2’s 5th child to build next frontier.
# Action     : Exploring operation 67+5=72.
# Resulting numbers: [53, 72].
# Heuristic score : (|53-20| + |72-20|)/2 = (33 + 52)/2 = 42.50
# Generated Node #0,2,4: 20:[53, 72] Operation: 67+5=72
#
# Thought    : Expand Node #0,2,4’s 1st child to build next frontier.
# Action     : Exploring operation 72-53=19.
# Resulting numbers: [19].
# 19,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,2 with lowest heuristic value 30.333333333333332
# Current State #0,2: 20:[67, 5, 53]. Operations so far : ['62-9=53'].
#
# Thought    : Expand Node #0,2’s 6th child to build next frontier.
# Action     : Exploring operation 53-67=10.
# Resulting numbers: [5, 10].
# Heuristic score : (|5-20| + |10-20|)/2 = (15 + 10)/2 = 12.50
# Generated Node #0,2,5: 20:[5, 10] Operation: 53-67=10
#
# Thought    : Expand Node #0,2,5’s 1st child to build next frontier.
# Action     : Exploring operation 5+10=15.
# Resulting numbers: [15].
# 15,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,2 with lowest heuristic value 30.333333333333332
# Current State #0,2: 20:[67, 5, 53]. Operations so far : ['62-9=53'].
#
# Thought    : Expand Node #0,2’s 7th child to build next frontier.
# Action     : Exploring operation 5*53=265.
# Resulting numbers: [67, 265].
# Heuristic score : (|67-20| + |265-20|)/2 = (47 + 245)/2 = 146.00
# Generated Node #0,2,6: 20:[67, 265] Operation: 5*53=265
#
# Thought    : Expand Node #0,2,6’s 1st child to build next frontier.
# Action     : Exploring operation 265-67=198.
# Resulting numbers: [198].
# 198,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,2 with lowest heuristic value 30.333333333333332
# Current State #0,2: 20:[67, 5, 53]. Operations so far : ['62-9=53'].
#
# Thought    : Expand Node #0,2’s 8th child to build next frontier.
# Action     : Exploring operation 67+53=120.
# Resulting numbers: [5, 120].
# Heuristic score : (|5-20| + |120-20|)/2 = (15 + 100)/2 = 57.50
# Generated Node #0,2,7: 20:[5, 120] Operation: 67+53=120
#
# Thought    : Expand Node #0,2,7’s 1st child to build next frontier.
# Action     : Exploring operation 120/5=24.
# Resulting numbers: [24].
# 24,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,2 with lowest heuristic value 30.333333333333332
# Current State #0,2: 20:[67, 5, 53]. Operations so far : ['62-9=53'].
#
# Thought    : Expand Node #0,2’s 9th child to build next frontier.
# Action     : Exploring operation 67*5=335.
# Resulting numbers: [53, 335].
# Heuristic score : (|53-20| + |335-20|)/2 = (33 + 315)/2 = 174.00
# Generated Node #0,2,8: 20:[53, 335] Operation: 67*5=335
#
# Thought    : Expand Node #0,2,8’s 1st child to build next frontier.
# Action     : Exploring operation 335-53=282.
# Resulting numbers: [282].
# 282,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,2 with lowest heuristic value 30.333333333333332
# Current State #0,2: 20:[67, 5, 53]. Operations so far : ['62-9=53'].
#
# Thought    : Expand Node #0,2’s 10th child to build next frontier.
# Action     : Exploring operation 67*53=3541.
# Resulting numbers: [5, 3541].
# Heuristic score : (|5-20| + |3541-20|)/2 = (15 + 3521)/2 = 1768.00
# Generated Node #0,2,9: 20:[5, 3541] Operation: 67*53=3541
#
# Thought    : Expand Node #0,2,9’s 1st child to build next frontier.
# Action     : Exploring operation 3541-5=3536.
# Resulting numbers: [3536].
# 3536,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0 with lowest heuristic value 29.5
# Current State #0: 20:[9, 62, 67, 5]. Operations so far : [].
#
# Thought    : Expand Node #0’s 4th child to build next frontier.
# Action     : Exploring operation 9+62=71.
# Resulting numbers: [67, 5, 71].
# Heuristic score : (|67-20| + |5-20| + |71-20|)/3 = (47 + 15 + 51)/3 = 37.50
# Generated Node #0,3: 20:[67, 5, 71] Operation: 9+62=71
#
# Thought    : Expand Node #0,3’s 1st child to build next frontier.
# Action     : Exploring operation 67-5=62.
# Resulting numbers: [71, 62].
# Heuristic score : (|71-20| + |62-20|)/2 = (51 + 42)/2 = 46.50
# Generated Node #0,3,0: 20:[71, 62] Operation: 67-5=62
#
# Thought    : Expand Node #0,3,0’s 1st child to build next frontier.
# Action     : Exploring operation 71-62=9.
# Resulting numbers: [9].
# 9,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,3 with lowest heuristic value 37.5
# Current State #0,3: 20:[67, 5, 71]. Operations so far : ['9+62=71'].
#
# Thought    : Expand Node #0,3’s 2nd child to build next frontier.
# Action     : Exploring operation 71-5=66.
# Resulting numbers: [67, 66].
# Heuristic score : (|67-20| + |66-20|)/2 = (47 + 46)/2 = 46.50
# Generated Node #0,3,1: 20:[67, 66] Operation: 71-5=66
#
# Thought    : Expand Node #0,3,1’s 1st child to build next frontier.
# Action     : Exploring operation 67-66=1.
# Resulting numbers: [1].
# 1,20 unequal: No Solution ... backtracking
#
# Thought    : Selecting next node to expand based on heuristic value
# Action     : Moving to Node #0,3 with lowest heuristic value 37.5
# Current State #0,3: 20:[67, 5, 71]. Operations so far : ['9+62=71'].
#
# Thought    : Expand Node #0,3’s 3rd child to build next frontier.
# Action     : Exploring operation 67-71=4.
# Resulting numbers: [5, 4].
# Heuristic score : (|5-20| + |4-20|)/2 = (15 + 16)/2 = 15.50
# Generated Node #0,3,2: 20:[5, 4] Operation: 67-71=4
#
# Thought    : Expand Node #0,3,2’s 1st child to build next frontier.
# Action     : Exploring operation 5*4=20.
# Resulting numbers: [20].
# 20,20 equal: Goal Reached
#
# ```
# SOLUTION: YES
# OPERATIONS: ['9+62=71', '67-71=4', '5*4=20']
# RESULT: 20
# ```
#
#
# ... 40 more trajectories not shown

# %%
print_trajectories_by_failure_type_from_df(trajectory_df, failure_type="incomplete", model_size="1.5B", dataset_type="search", dataset_size="5k", limit=1)
# Out:
# Found 51 trajectories matching criteria
#
# --- Trajectory 0 ---
# Model: 1.5B search 4k 5k
# Problem: [53, 57, 13, 48]
# Target: 64
# Token count: 10141
#
# Completion:
# system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.
# user
# Combine these initial numbers [53, 57, 13, 48] using only arithmetic operations (+, -, *, /) to reach the target value 64. All initial numbers must be used exactly once.
# Conclude with the final result in EXACTLY this format:
# ```
# SOLUTION: YES/NO
# OPERATIONS: list of string of operations performed, each string involving only 1 operation. For example, ['A+B=C','C+D=E'] is allowed, ['A+B+D=E'] is not allowed
# RESULT: final_value
# ```
#
# assistant
# Current State: 64:[53, 57, 13, 48], Operations: []
# Exploring Operation: 13+48=61, Resulting Numbers: [53, 57, 61]
# Generated Node #0,0: 64:[53, 57, 61] Operation: 13+48=61
# Exploring Operation: 53-13=40, Resulting Numbers: [57, 48, 40]
# Generated Node #0,1: 64:[57, 48, 40] Operation: 53-13=40
# Exploring Operation: 53+13=66, Resulting Numbers: [57, 48, 66]
# Generated Node #0,2: 64:[57, 48, 66] Operation: 53+13=66
# Exploring Operation: 57-13=44, Resulting Numbers: [53, 48, 44]
# Generated Node #0,3: 64:[53, 48, 44] Operation: 57-13=44
# Exploring Operation: 57+13=70, Resulting Numbers: [53, 48, 70]
# Generated Node #0,4: 64:[53, 48, 70] Operation: 57+13=70
# Moving to Node #0,0
# Current State: 64:[53, 57, 61], Operations: ['13+48=61']
# Exploring Operation: 61-53=8, Resulting Numbers: [57, 8]
# Generated Node #0,0,0: 64:[57, 8] Operation: 61-53=8
# Exploring Operation: 53+57=110, Resulting Numbers: [61, 110]
# Generated Node #0,0,1: 64:[61, 110] Operation: 53+57=110
# Exploring Operation: 57-53=4, Resulting Numbers: [61, 4]
# Generated Node #0,0,2: 64:[61, 4] Operation: 57-53=4
# Exploring Operation: 53+61=114, Resulting Numbers: [57, 114]
# Generated Node #0,0,3: 64:[57, 114] Operation: 53+61=114
# Exploring Operation: 57+61=118, Resulting Numbers: [53, 118]
# Generated Node #0,0,4: 64:[53, 118] Operation: 57+61=118
# Moving to Node #0,2
# Current State: 64:[57, 48, 66], Operations: ['53+13=66']
# Exploring Operation: 57-48=9, Resulting Numbers: [66, 9]
# Generated Node #0,2,0: 64:[66, 9] Operation: 57-48=9
# Exploring Operation: 57+66=123, Resulting Numbers: [48, 123]
# Generated Node #0,2,1: 64:[48, 123] Operation: 57+66=123
# Exploring Operation: 66-48=18, Resulting Numbers: [57, 18]
# Generated Node #0,2,2: 64:[57, 18] Operation: 66-48=18
# Exploring Operation: 48+66=114, Resulting Numbers: [57, 114]
# Generated Node #0,2,3: 64:[57, 114] Operation: 48+66=114
# Exploring Operation: 57+48=105, Resulting Numbers: [66, 105]
# Generated Node #0,2,4: 64:[66, 105] Operation: 57+48=105
# Moving to Node #0,4
# Current State: 64:[53, 48, 70], Operations: ['57+13=70']
# Exploring Operation: 53+48=101, Resulting Numbers: [70, 101]
# Generated Node #0,4,0: 64:[70, 101] Operation: 53+48=101
# Exploring Operation: 70-53=17, Resulting Numbers: [48, 17]
# Generated Node #0,4,1: 64:[48, 17] Operation: 70-53=17
# Exploring Operation: 53-48=5, Resulting Numbers: [70, 5]
# Generated Node #0,4,2: 64:[70, 5] Operation: 53-48=5
# Exploring Operation: 70-48=22, Resulting Numbers: [53, 22]
# Generated Node #0,4,3: 64:[53, 22] Operation: 70-48=22
# Exploring Operation: 48+70=118, Resulting Numbers: [53, 118]
# Generated Node #0,4,4: 64:[53, 118] Operation: 48+70=118
# Moving to Node #0,1
# Current State: 64:[57, 48, 40], Operations: ['53-13=40']
# Exploring Operation: 48+40=88, Resulting Numbers: [57, 88]
# Generated Node #0,1,0: 64:[57, 88] Operation: 48+40=88
# Exploring Operation: 57-40=17, Resulting Numbers: [48, 17]
# Generated Node #0,1,1: 64:[48, 17] Operation: 57-40=17
# Exploring Operation: 57+40=97, Resulting Numbers: [48, 97]
# Generated Node #0,1,2: 64:[48, 97] Operation: 57+40=97
# Exploring Operation: 57+48=105, Resulting Numbers: [40, 105]
# Generated Node #0,1,3: 64:[40, 105] Operation: 57+48=105
# Exploring Operation: 48-40=8, Resulting Numbers: [57, 8]
# Generated Node #0,1,4: 64:[57, 8] Operation: 48-40=8
# Moving to Node #0,3
# Current State: 64:[53, 48, 44], Operations: ['57-13=44']
# Exploring Operation: 53-44=9, Resulting Numbers: [48, 9]
# Generated Node #0,3,0: 64:[48, 9] Operation: 53-44=9
# Exploring Operation: 48-44=4, Resulting Numbers: [53, 4]
# Generated Node #0,3,1: 64:[53, 4] Operation: 48-44=4
# Exploring Operation: 53+48=101, Resulting Numbers: [44, 101]
# Generated Node #0,3,2: 64:[44, 101] Operation: 53+48=101
# Exploring Operation: 53+44=97, Resulting Numbers: [48, 97]
# Generated Node #0,3,3: 64:[48, 97] Operation: 53+44=97
# Exploring Operation: 48+44=92, Resulting Numbers: [53, 92]
# Generated Node #0,3,4: 64:[53, 92] Operation: 48+44=92
# Moving to Node #0,4,0
# Current State: 64:[70, 101], Operations: ['57+13=70', '53+48=101']
# Exploring Operation: 101-70=31, Resulting Numbers: [31]
# 31,64 unequal: No Solution
#
# Exploring Operation: 70*101=7070, Resulting Numbers: [7070]
# 7070,64 unequal: No Solution
#
# Exploring Operation: 70+101=171, Resulting Numbers: [171]
# 171,64 unequal: No Solution
#
# Moving to Node #0,2,4
# Current State: 64:[66, 105], Operations: ['53+13=66', '57+48=105']
# Exploring Operation: 66*105=6870, Resulting Numbers: [6870]
# 6870,64 unequal: No Solution
#
# Exploring Operation: 66+105=171, Resulting Numbers: [171]
# 171,64 unequal: No Solution
#
# Exploring Operation: 105-66=39, Resulting Numbers: [39]
# 39,64 unequal: No Solution
#
# Moving to Node #0,1,0
# Current State: 64:[57, 88], Operations: ['53-13=40', '48+40=88']
# Exploring Operation: 57+88=145, Resulting Numbers: [145]
# 145,64 unequal: No Solution
#
# Exploring Operation: 88-57=31, Resulting Numbers: [31]
# 31,64 unequal: No Solution
#
# Exploring Operation: 57*88=5016, Resulting Numbers: [5016]
# 5016,64 unequal: No Solution
#
# Moving to Node #0,3,4
# Current State: 64:[53, 92], Operations: ['57-13=44', '48+44=92']
# Exploring Operation: 92-53=39, Resulting Numbers: [39]
# 39,64 unequal: No Solution
#
# Exploring Operation: 53*92=4876, Resulting Numbers: [4876]
# 4876,64 unequal: No Solution
#
# Exploring Operation: 53+92=145, Resulting Numbers: [145]
# 145,64 unequal: No Solution
#
# Moving to Node #0,0,1
# Current State: 64:[61, 110], Operations: ['13+48=61', '53+57=110']
# Exploring Operation: 61*110=6710, Resulting Numbers: [6710]
# 6710,64 unequal: No Solution
#
# Exploring Operation: 61+110=171, Resulting Numbers: [171]
# 171,64 unequal: No Solution
#
# Exploring Operation: 110-61=49, Resulting Numbers: [49]
# 49,64 unequal: No Solution
#
# Moving to Node #0,1,2
# Current State: 64:[48, 97], Operations: ['53-13=40', '57+40=97']
# Exploring Operation: 48*97=4752, Resulting Numbers: [4752]
# 4752,64 unequal: No Solution
#
# Exploring Operation: 97-48=49, Resulting Numbers: [49]
# 49,64 unequal: No Solution
#
# Exploring Operation: 48+97=145, Resulting Numbers: [145]
# 145,64 unequal: No Solution
#
# Moving to Node #0,1,0,1
# Current State: 64:[31], Operations: ['53-13=40', '48+40=88', '88-57=31']
# Moving to Node #0,1,2,1
# Current State: 64:[49], Operations: ['53-13=40', '57+40=97', '97-48=49']
# Moving to Node #0,0,1,2
# Current State: 64:[49], Operations: ['13+48=61', '53+57=110', '110-61=49']
# Moving to Node #0,3,4,0
# Current State: 64:[39], Operations: ['57-13=44', '48+44=92', '92-53=39']
# Moving to Node #0,2,4,2
# Current State: 64:[39], Operations: ['53+13=66', '57+48=105', '105-66=39']
# Moving to Node #0,3,3
# Current State: 64:[48, 97], Operations: ['57-13=44', '53+44=97']
# Exploring Operation: 48+97=145, Resulting Numbers: [145]
# 145,64 unequal: No Solution
#
# Exploring Operation: 97-48=49, Resulting Numbers: [49]
# 49,64 unequal: No Solution
#
# Exploring Operation: 48*97=4752, Resulting Numbers: [4752]
# 4752,64 unequal: No Solution
#
# Moving to Node #0,3,3,1
# Current State: 64:[49], Operations: ['57-13=44', '53+44=97', '97-48=49']
# Moving to Node #0,3,2
# Current State: 64:[44, 101], Operations: ['57-13=44', '53+48=101']
# Exploring Operation: 44*101=4444, Resulting Numbers: [4444]
# 4444,64 unequal: No Solution
#
# Exploring Operation: 101-44=57, Resulting Numbers: [57]
# 57,64 unequal: No Solution
#
# Exploring Operation: 44+101=145, Resulting Numbers: [145]
# 145,64 unequal: No Solution
#
# Moving to Node #0,3,3,0
# Current State: 64:[145], Operations: ['57-13=44', '53+44=97', '48+97=145']
# Moving to Node #0,3,2,1
# Current State: 64:[57], Operations: ['57-13=44', '53+48=101', '101-44=57']
# Moving to Node #0,0,3
# Current State: 64:[57, 114], Operations: ['13+48=61', '53+61=114']
# Exploring Operation: 114-57=57, Resulting Numbers: [57]
# 57,64 unequal: No Solution
#
# Exploring Operation: 57+114=171, Resulting Numbers: [171]
# 171,64 unequal: No Solution
#
# Exploring Operation: 57*114=6598, Resulting Numbers: [6598]
# 6598,64 unequal: No Solution
#
# Moving to Node #0,0,3,0
# Current State: 64:[57], Operations: ['13+48=61', '53+61=114', '114-57=57']
# Moving to Node #0,2,3
# Current State: 64:[57, 114], Operations: ['53+13=66', '48+66=114']
# Exploring Operation: 114-57=57, Resulting Numbers: [57]
# 57,64 unequal: No Solution
#
# Exploring Operation: 57*114=6598, Resulting Numbers: [6598]
# 6598,64 unequal: No Solution
#
# Exploring Operation: 57+114=171, Resulting Numbers: [171]
# 171,64 unequal: No Solution
#
# Moving to Node #0,2,0
# Current State: 64:[66, 9], Operations: ['53+13=66', '57-48=9']
# Exploring Operation: 66-9=57, Resulting Numbers: [57]
# 57,64 unequal: No Solution
#
# Exploring Operation: 66+9=75, Resulting Numbers: [75]
# 75,64 unequal: No Solution
#
# Exploring Operation: 66*9=594, Resulting Numbers: [594]
# 594,64 unequal: No Solution
#
# Moving to Node #0,0,2
# Current State: 64:[61, 4], Operations: ['13+48=61', '57-53=4']
# Exploring Operation: 61-4=57, Resulting Numbers: [57]
# 57,64 unequal: No Solution
#
# Exploring Operation: 61*4=244, Resulting Numbers: [244]
# 244,64 unequal: No Solution
#
# Exploring Operation: 61+4=65, Resulting Numbers: [65]
# 65,64 unequal: No Solution
#
# Moving to Node #0,0,2,2
# Current State: 64:[65], Operations: ['13+48=61', '57-53=4', '61+4=65']
# Moving to Node #0,2,0,0
# Current State: 64:[57], Operations: ['53+13=66', '57-48=9', '66-9=57']
# Moving to Node #0,2,0,1
# Current State: 64:[75], Operations: ['53+13=66', '57-48=9', '66+9=75']
# Moving to Node #0,0,2,0
# Current State: 64:[57], Operations: ['13+48=61', '57-53=4', '61-4=57']
# Moving to Node #0,2,3,0
# Current State: 64:[57], Operations: ['53+13=66', '48+66=114', '114-57=57']
# Moving to Node #0,4,3
# Current State: 64:[53, 22], Operations: ['57+13=70', '70-48=22']
# Exploring Operation: 53*22=1166, Resulting Numbers: [1166]
# 1166,64 unequal: No Solution
#
# Exploring Operation: 53+22=75, Resulting Numbers: [75]
# 75,64 unequal: No Solution
#
# Exploring Operation: 53-22=31, Resulting Numbers: [31]
# 31,64 unequal: No Solution
#
# Moving to Node #0,4,3,1
# Current State: 64:[75], Operations: ['57+13=70', '70-48=22', '53+22=75']
# Moving to Node #0,4,3,2
# Current State: 64:[31], Operations: ['57+13=70', '70-48=22', '53-22=31']
# Moving to Node #0,1,1
# Current State: 64:[48, 17], Operations: ['53-13=40', '57-40=17']
# Exploring Operation: 48-17=31, Resulting Numbers: [31]
# 31,64 unequal: No Solution
#
# Exploring Operation: 48*17=816, Resulting Numbers: [816]
# 816,64 unequal: No Solution
#
# Exploring Operation: 48+17=65, Resulting Numbers: [65]
# 65,64 unequal: No Solution
#
# Moving to Node #0,1,4
# Current State: 64:[57, 8], Operations: ['53-13=40', '48-40=8']
# Exploring Operation: 57*8=456, Resulting Numbers: [456]
# 456,64 unequal: No Solution
#
# Exploring Operation: 57-8=49, Resulting Numbers: [49]
# 49,64 unequal: No Solution
#
# Exploring Operation: 57+8=65, Resulting Numbers: [65]
# 65,64 unequal: No Solution
#
# Moving to Node #0,1,1,2
# Current State: 64:[65], Operations: ['53-13=40', '57-40=17', '48+17=65']
# Moving to Node #0,1,4,2
# Current State: 64:[65], Operations: ['53-13=40', '48-40=8', '57+8=65']
# Moving to Node #0,1,4,1
# Current State: 64:[49], Operations: ['53-13=40', '48-40=8', '57-8=49']
# Moving to Node #0,2,2
# Current State: 64:[57, 18], Operations: ['53+13=66', '66-48=18']
# Exploring Operation: 57-18=39, Resulting Numbers: [39]
# 39,64 unequal: No Solution
#
# Exploring Operation: 57*18=1026, Resulting Numbers: [1026]
# 1026,64 unequal: No Solution
#
# Exploring Operation: 57+18=75, Resulting Numbers: [75]
# 75,64 unequal: No Solution
#
# Moving to Node #0,0,0
# Current State: 64:[57, 8], Operations: ['13+48=61', '61-53=8']
# Exploring Operation: 57*8=456, Resulting Numbers: [456]
# 456,64 unequal: No Solution
#
# Exploring Operation: 57+8=65, Resulting Numbers: [65]
# 65,64 unequal: No Solution
#
# Exploring Operation: 57-8=49, Resulting Numbers: [49]
# 49,64 unequal: No Solution
#
# Moving to Node #0,2,2,2
# Current State: 64:[75], Operations: ['53+13=66', '66-48=18', '57+18=75']
# Moving to Node #0,0,0,1
# Current State: 64:[65], Operations: ['13+48=61', '61-53=8', '57+8=65']
# Moving to Node #0,0,0,2
# Current State: 64:[49], Operations: ['13+48=61', '61-53=8', '57-8=49']
# Moving to Node #0,2,2,0
# Current State: 64:[39], Operations: ['53+13=66', '66-48=18', '57-18=39']
# Moving to Node #0,4,1
# Current State: 64:[48, 17], Operations: ['57+13=70', '70-53=17']
# Exploring Operation: 48+17=65, Resulting Numbers: [65]
# 65,64 unequal: No Solution
#
# Exploring Operation: 48-17=31, Resulting Numbers: [31]
# 31,64 unequal: No Solution
#
# Exploring Operation: 48*17=816, Resulting Numbers: [816]
# 816,64 unequal: No Solution
#
# Moving to Node #0,4,1,0
# Current State: 64:[65], Operations: ['57+13=70', '70-53=17', '48+17=65']
# Moving to Node #0,4,1,1
# Current State: 64:[31], Operations: ['57+13=70', '70-53=17', '48-17=31']
# Moving to Node #0,1,1,0
# Current State: 64:[31], Operations: ['53-13=40', '57-40=17', '48-17=31']
# Moving to Node #0,3,0
# Current State: 64:[48, 9], Operations: ['57-13=44', '53-44=9']
# Exploring Operation: 48*9=432, Resulting Numbers: [432]
# 432,64 unequal: No Solution
#
# Exploring Operation: 48-9=39, Resulting Numbers: [39]
# 39,64 unequal: No Solution
#
# Exploring Operation: 48+9=57, Resulting Numbers: [57]
# 57,64 unequal: No Solution
#
# Moving to Node #0,3,0,2
# Current State: 64:[57], Operations: ['57-13=44', '53-44=9', '48+9=57']
# Moving to Node #0,3,0,1
# Current State: 64:[39], Operations: ['57-13=44', '53-44=9', '48-9=39']
# Moving to Node #0,1,3
# Current State: 64:[40, 105], Operations: ['53-13=40', '57+48=105']
# Exploring Operation: 40+105=145, Resulting Numbers: [145]
# 145,64 unequal: No Solution
#
# Exploring Operation: 40*105=4200, Resulting Numbers: [4200]
# 4200,64 unequal: No Solution
#
# Exploring Operation: 105-40=65, Resulting Numbers: [65]
# 65,64 unequal: No Solution
#
# Moving to Node #0,4,2
# Current State: 64:[70, 5], Operations: ['57+13=70', '53-48=5']
# Exploring Operation: 70*5=350, Resulting Numbers: [350]
# 350,64 unequal: No Solution
#
# Exploring Operation: 70+5=75, Resulting Numbers: [75]
# 75,64 unequal: No Solution
#
# Exploring Operation: 70-5=65, Resulting Numbers: [65]
# 65,64 unequal: No Solution
#
# Exploring Operation: 70/5=14, Resulting Numbers: [14]
# 14,64 unequal: No Solution
#
# Moving to Node #0,4,4
# Current State: 64:[53, 118], Operations: ['57+13=70', '48+70=118']
# Exploring Operation: 118-53=65, Resulting Numbers: [65]
# 65,64 unequal: No Solution
#
# Exploring Operation: 53+118=171, Resulting Numbers: [171]
# 171,64 unequal: No Solution
#
# Exploring Operation: 53*118=6314, Resulting Numbers: [6314]
# 6314,64 unequal: No Solution
#
# Moving to Node #0,1,3,2
# Current State: 64:[65], Operations: ['53-13=40', '57+48=105', '105-40=65']
# Moving to Node #0,4,2,2
# Current State: 64:[65], Operations: ['57+13=70', '53-48=5', '70-5=65']
# Moving to Node #0,4,2,1
# Current State: 64:[75], Operations: ['57+13=70', '53-48=5', '70+5=75']
# Moving to Node #0,4,4,0
# Current State: 64:[65], Operations: ['57+13=70', '48+70=118', '118-53=65']
# Moving to Node #0,1,3,0
# Current State: 64:[145], Operations: ['53-13=40', '57+48=105', '40+105=145']
# Moving to Node #0,0,4
# Current State: 64:[53, 118], Operations: ['13+48=61', '57+61=118']
# Exploring Operation: 53+118=171, Resulting Numbers: [171]
# 171,64 unequal: No Solution
#
# Exploring Operation: 53*118=6314, Resulting Numbers: [6314]
# 6314,64 unequal: No Solution
#
# Exploring Operation: 118-53=65, Resulting Numbers: [65]
# 65,64 unequal: No Solution
#
# Moving to Node #0,1,2,2
# Current State: 64:[145], Operations: ['53-13=40', '57+40=97', '48+97=145']
# Moving to Node #0,3,2,2
# Current State: 64:[145], Operations: ['57-13=44', '53+44=97', '48+97=145']
# Moving to Node #0,0,4,2
# Current State: 64:[65], Operations: ['13+48=61', '57+61=118', '118-53=65']
# Moving to Node #0,4,4,1
# Current State: 64:[171], Operations: ['57+13=70', '48+70=118', '53+118=171']
# Moving to Node #0,0,3,1
# Current State: 64:[171], Operations: ['13+48=61', '53+61=114', '57+114=171']
# Moving to Node #0,0,4,0
# Current State: 64:[171], Operations: ['13+48=61', '57+61=118', '53+118=171']
# Moving to Node #0,3,3,2
# Current State: 64:[145], Operations: ['57-13=44', '53+44=97', '48+97=145']
# Moving to Node #0,2,4,1
# Current State: 64:[171], Operations: ['53+13=66', '57+48=105', '66+105=171']
# Moving to Node #0,1,0,0
# Current State: 64:[145], Operations: ['53-13=40', '48+40=88', '57+88=145']
# Moving to Node #0,4,0,0
# Current State: 64:[101], Operations: ['57+13=70', '53+48=101', '70+101=101']
# Moving to Node #0,4,2,3
# Current State: 64:[14], Operations: ['57+13=70', '53-48=5', '70/5=14']
# Moving to Node #0,2,1
# Current State: 64:[48, 123], Operations: ['53+13=66', '57+66=123']
# Exploring Operation: 48+123=171, Resulting Numbers: [171]
# 171,64 unequal: No Solution
#
# Exploring Operation: 48*123=5864, Resulting Numbers: [5864]
# 5864,64 unequal: No Solution
#
# Exploring Operation: 123-48=75, Resulting Numbers: [75]
# 75,64 unequal: No Solution
#
# Moving to Node #0,2,1,2
# Current State: 64:[75], Operations: ['53+13=66', '57+66=123', '123-48=75']
# Moving to Node #0,0,1,1
# Current State: 64:[171], Operations: ['13+48=61', '53+57=110', '61+110=171']
# Moving to Node #0,2,3,2
# Current State: 64:[171], Operations: ['53+13=66', '48+66=114', '57+114=171']
# Moving to Node #0,4,3,0
# Current State: 64:[1166], Operations: ['57+13=70', '70-48=22', '53*22=1166']
# Moving to Node #0,1,4,0
# Current State: 64:[456], Operations: ['53-13=40', '48-40=8', '57*8=456']
# Moving to Node #0,1,1,1
# Current State: 64:[816], Operations: ['53-13=40', '57-40=17', '48*17=816']
# Moving to Node #0,0,2,1
# Current State: 64:[244], Operations: ['13+48=61', '57-53=4', '61*4=244']
# Moving to Node #0,3,0,0
# Current State: 64:[432], Operations: ['57-13=44', '53-44=9', '48*9=432']
# Moving to Node #0,2,2,1
# Current State: 64:[1026], Operations: ['53+13=66', '66-48=18', '57*18=1026']
# Moving to Node #0,0,3,2
# Current State: 64:[6598], Operations: ['13+48=61', '53+61=114', '57*114=6598']
# Moving to Node #0,2,0,2
# Current State: 64:[594], Operations: ['53+13=66', '57-48=9', '66*9=594']
# Moving to Node #0,1,2,0
# Current State: 64:[816], Operations: ['53-13=40', '57+40=97', '48*97=816']
# Moving to Node #0,4,4,2
# Current State: 64:[6314], Operations: ['57+13=70', '48+70=118', '53*118=6314']
# Moving to Node #0,0,4,1
# Current State: 64:[6314], Operations: ['13+48=61', '57+61=118', '53*118=6314']
# Moving to Node #0,4,0,2
# Current State: 64:[7070], Operations: ['57+13=70', '53+48=101', '70*101=7070']
# Moving to Node #0,1,0,2
# Current State: 64:[14568], Operations: ['53-13=40', '48+40=88', '57*88=14568']
# Moving to Node #0,2,4,0
# Current State: 64:[6870], Operations: ['53+13=66', '57+48=105', '66*105=6870']
# Moving to Node #0,3,3,0
# Current State: 64:[1452], Operations: ['57-13=44', '53+44=97', '48*97=1452']
# Moving to Node #0,3,2,0
# Current State: 64:[4416], Operations: ['57-13=44', '53+48=101', '48*101=4416']
# Moving to Node #0,2,1,0
# Current State: 64:[171], Operations: ['53+13=66', '57+66=123', '48+123=171']
# Moving to Node #0,4,2,0
# Current State: 64:[350], Operations: ['57+13=70', '53-48=5', '70*5=350']
# Moving to Node #0,4,1,2
# Current State: 64:[816], Operations: ['57+13=70', '70-53=17', '48*17=816']
# Moving to Node #0,3,0,1
# Current State: 64:[39], Operations: ['57-13=44', '53-44=9', '48-9=39']
# Moving to Node #0,3,4,2
# Current State: 64:[145], Operations: ['57-13=44', '48+44=92', '53+92=145']
# Moving to Node #0,2,3,1
# Current State: 64:[4200], Operations: ['53+13=66', '48+66=114', '57*114=4200']
# Moving to Node #0,4,3,2
# Current State: 64:[816], Operations: ['57+13=70', '70-48=22', '53*22=816']
# Moving to Node #0,1,3,1
# Current State: 64:[4200], Operations: ['53-13=40', '57+48=105', '40*105=4200']
# Moving to Node #0,0,0,0
# Current State: 64:[456], Operations: ['13+48=61', '61-53=8', '57*8=456']
# Moving to Node #0,0,1,0
# Current State: 64:[6710], Operations: ['13+48=61', '53+57=110', '61*110=6710']
# Moving to Node #0,1,1,3
# Current State: 64:[3120], Operations: ['53-13=40', '57-40=17', '48*17=3120']
# Moving to Node #0,4,4,3
# Current State: 64:[1714], Operations: ['57+13=70', '48+70=118', '53*118=1714']
# Moving to Node #0,4,2,2
# Current State: 64:[70], Operations: ['57+13=70', '53-48=5', '70/5=14']
# Moving to Node #0,1,4,2
# Current State: 64:[49], Operations: ['53-13=40', '48-40=8', '57-8=49']
# Moving to Node #0,1,1,0
# Current State: 64:[31], Operations: ['53-13=40', '57-40=17', '48-17=31']
# Moving to Node #0,1,3,1
# Current State: 64:[4200], Operations: ['53-13=40', '57+48=
#
# ... 50 more trajectories not shown
